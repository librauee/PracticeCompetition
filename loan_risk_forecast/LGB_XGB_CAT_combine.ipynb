# %%
"""
作者：librauee
微信公众号：老肥码码码
日期：2020.12.15
线上得分：0.816
截至日期排名：1
"""
import pandas as pd
from tqdm import tqdm
import warnings
import lightgbm as lgb
import numpy as np
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import roc_auc_score, accuracy_score

warnings.filterwarnings('ignore')
KF = StratifiedKFold(n_splits=5, shuffle=True, random_state=2020)

# %%
# 数据读取，去除无关列和标签列
train = pd.read_csv('train.csv')
test = pd.read_csv('test_noLabel.csv')
X_train = train.drop(['uid', 'y'], axis=1)
y = train['y']
X_test = test.drop(['uid'],  axis=1)
features = X_train.columns

# %%
# LGB模型五折交叉验证
params = {
          'objective':'binary',
          'metric':'binary_error', 
          'learning_rate':0.05, 
          'subsample':0.8, 
          'subsample_freq':3, 
          'colsample_btree':0.8,
          'num_iterations': 10000, 
}

oof_lgb = np.zeros(len(X_train))
predictions_lgb = np.zeros((len(X_test)))

for fold_, (trn_idx, val_idx) in enumerate(KF.split(X_train.values, y.values)):
    print("fold n°{}".format(fold_))
    print('trn_idx:',trn_idx)
    print('val_idx:',val_idx)
    trn_data = lgb.Dataset(X_train.iloc[trn_idx][features],label=y.iloc[trn_idx])    
    val_data = lgb.Dataset(X_train.iloc[val_idx][features],label=y.iloc[val_idx])
    num_round = 10000
    clf = lgb.train(
        params,
                    trn_data,
                    num_round,
                    valid_sets = [trn_data, val_data],
                    verbose_eval=500,
                    early_stopping_rounds=200,  
    )
        
    oof_lgb[val_idx] = clf.predict(X_train.iloc[val_idx][features], num_iteration=clf.best_iteration)
    predictions_lgb[:] += clf.predict(X_test[features], num_iteration=clf.best_iteration) / 5
print("AUC score: {}".format(roc_auc_score(y, oof_lgb)))
print("ACC score: {}".format(accuracy_score(y, [1 if i >= 0.5 else 0 for i in oof_lgb])))
# Out:
# fold n°0
# trn_idx: [   2    3    4 ... 7996 7997 7998]
# val_idx: [   0    1   44 ... 7990 7995 7999]
# Training until validation scores don't improve for 200 rounds
# Early stopping, best iteration is:
# [189]	training's binary_error: 0.107344	valid_1's binary_error: 0.206875
# fold n°1
# trn_idx: [   0    1    2 ... 7997 7998 7999]
# val_idx: [  15   28   35 ... 7986 7993 7996]
# Training until validation scores don't improve for 200 rounds
# [500]	training's binary_error: 0.0151562	valid_1's binary_error: 0.19375
# Early stopping, best iteration is:
# [792]	training's binary_error: 0.0009375	valid_1's binary_error: 0.186875
# fold n°2
# trn_idx: [   0    1    2 ... 7997 7998 7999]
# val_idx: [   3    4   14 ... 7977 7978 7994]
# Training until validation scores don't improve for 200 rounds
# Early stopping, best iteration is:
# [128]	training's binary_error: 0.135	valid_1's binary_error: 0.188125
# fold n°3
# trn_idx: [   0    1    3 ... 7995 7996 7999]
# val_idx: [   2    6    8 ... 7992 7997 7998]
# Training until validation scores don't improve for 200 rounds
# Early stopping, best iteration is:
# [262]	training's binary_error: 0.075	valid_1's binary_error: 0.198125
# fold n°4
# trn_idx: [   0    1    2 ... 7997 7998 7999]
# val_idx: [   5    7   10 ... 7979 7985 7989]
# Training until validation scores don't improve for 200 rounds
# Early stopping, best iteration is:
# [126]	training's binary_error: 0.1375	valid_1's binary_error: 0.19
# AUC score: 0.8026770909756176
# ACC score: 0.806

# %%
# XGB模型五折交叉验证
import xgboost as xgb
oof_xgb = np.zeros(len(X_train))
predictions_xgb = np.zeros((len(X_test)))

for fold_, (trn_idx, val_idx) in enumerate(KF.split(X_train.values, y.values)):
    print("fold n°{}".format(fold_))
    print('trn_idx:',trn_idx)
    print('val_idx:',val_idx)

    X_trn, X_val = X_train.iloc[trn_idx], X_train.iloc[val_idx]
    y_trn, y_val = y.iloc[trn_idx], y.iloc[val_idx]

    model = xgb.XGBClassifier(n_estimators=9999,
                               tree_method='gpu_hist',
                                  )
    model.fit(X_trn[features], y_trn, early_stopping_rounds=200, verbose=100, 
              eval_set=[(X_trn[features], y_trn), (X_val[features], y_val)], eval_metric=['error'])
        
    oof_xgb[val_idx] = model.predict(X_train.iloc[val_idx][features])
    predictions_xgb[:] += model.predict(X_test[features]) / 5
print("AUC score: {}".format(roc_auc_score(y, oof_xgb)))
print("ACC score: {}".format(accuracy_score(y, [1 if i >= 0.5 else 0 for i in oof_xgb])))
# Out:
# fold n°0
# trn_idx: [   2    3    4 ... 7996 7997 7998]
# val_idx: [   0    1   44 ... 7990 7995 7999]
# [0]	validation_0-error:0.20859	validation_1-error:0.25875
# [1]	validation_0-error:0.20016	validation_1-error:0.24000
# [2]	validation_0-error:0.19172	validation_1-error:0.23125
# [3]	validation_0-error:0.19016	validation_1-error:0.23375
# [4]	validation_0-error:0.18688	validation_1-error:0.22750
# [5]	validation_0-error:0.17969	validation_1-error:0.22250
# [6]	validation_0-error:0.17484	validation_1-error:0.22187
# [7]	validation_0-error:0.16875	validation_1-error:0.22125
# [8]	validation_0-error:0.16641	validation_1-error:0.22062
# [9]	validation_0-error:0.16219	validation_1-error:0.21875
# [10]	validation_0-error:0.16062	validation_1-error:0.21688
# [11]	validation_0-error:0.15750	validation_1-error:0.22062
# [12]	validation_0-error:0.15734	validation_1-error:0.22125
# [13]	validation_0-error:0.15641	validation_1-error:0.22187
# [14]	validation_0-error:0.15328	validation_1-error:0.22187
# [15]	validation_0-error:0.15266	validation_1-error:0.21937
# [16]	validation_0-error:0.15188	validation_1-error:0.21937
# [17]	validation_0-error:0.15109	validation_1-error:0.22000
# [18]	validation_0-error:0.15000	validation_1-error:0.22000
# [19]	validation_0-error:0.14656	validation_1-error:0.21688
# [20]	validation_0-error:0.14406	validation_1-error:0.21563
# [21]	validation_0-error:0.14109	validation_1-error:0.21813
# [22]	validation_0-error:0.13828	validation_1-error:0.21688
# [23]	validation_0-error:0.13687	validation_1-error:0.21563
# [24]	validation_0-error:0.13531	validation_1-error:0.21500
# [25]	validation_0-error:0.13172	validation_1-error:0.21500
# [26]	validation_0-error:0.13047	validation_1-error:0.21563
# [27]	validation_0-error:0.12594	validation_1-error:0.21375
# [28]	validation_0-error:0.12656	validation_1-error:0.21313
# [29]	validation_0-error:0.12266	validation_1-error:0.21813
# [30]	validation_0-error:0.11844	validation_1-error:0.21438
# [31]	validation_0-error:0.11672	validation_1-error:0.21688
# [32]	validation_0-error:0.11344	validation_1-error:0.21250
# [33]	validation_0-error:0.11109	validation_1-error:0.21125
# [34]	validation_0-error:0.10984	validation_1-error:0.21313
# [35]	validation_0-error:0.10547	validation_1-error:0.21313
# [36]	validation_0-error:0.10328	validation_1-error:0.21313
# [37]	validation_0-error:0.10156	validation_1-error:0.21188
# [38]	validation_0-error:0.09938	validation_1-error:0.21250
# [39]	validation_0-error:0.09766	validation_1-error:0.21063
# [40]	validation_0-error:0.09641	validation_1-error:0.20625
# [41]	validation_0-error:0.09250	validation_1-error:0.20875
# [42]	validation_0-error:0.09219	validation_1-error:0.21313
# [43]	validation_0-error:0.08984	validation_1-error:0.21250
# [44]	validation_0-error:0.08906	validation_1-error:0.21188
# [45]	validation_0-error:0.08719	validation_1-error:0.21500
# [46]	validation_0-error:0.08563	validation_1-error:0.21375
# [47]	validation_0-error:0.08391	validation_1-error:0.21313
# [48]	validation_0-error:0.08078	validation_1-error:0.21688
# [49]	validation_0-error:0.08031	validation_1-error:0.21688
# [50]	validation_0-error:0.08031	validation_1-error:0.21750
# [51]	validation_0-error:0.08047	validation_1-error:0.21563
# [52]	validation_0-error:0.07781	validation_1-error:0.21563
# [53]	validation_0-error:0.07750	validation_1-error:0.21438
# [54]	validation_0-error:0.07375	validation_1-error:0.21125
# [55]	validation_0-error:0.07344	validation_1-error:0.21188
# [56]	validation_0-error:0.07031	validation_1-error:0.20813
# [57]	validation_0-error:0.07016	validation_1-error:0.20750
# [58]	validation_0-error:0.07016	validation_1-error:0.20938
# [59]	validation_0-error:0.06875	validation_1-error:0.21063
# [60]	validation_0-error:0.06672	validation_1-error:0.21125
# [61]	validation_0-error:0.06531	validation_1-error:0.21250
# [62]	validation_0-error:0.06375	validation_1-error:0.21125
# [63]	validation_0-error:0.06359	validation_1-error:0.21125
# [64]	validation_0-error:0.06313	validation_1-error:0.21063
# [65]	validation_0-error:0.06125	validation_1-error:0.20938
# [66]	validation_0-error:0.06109	validation_1-error:0.21000
# [67]	validation_0-error:0.06062	validation_1-error:0.21000
# [68]	validation_0-error:0.06031	validation_1-error:0.21000
# [69]	validation_0-error:0.05906	validation_1-error:0.21000
# [70]	validation_0-error:0.05766	validation_1-error:0.20938
# [71]	validation_0-error:0.05547	validation_1-error:0.21125
# [72]	validation_0-error:0.05375	validation_1-error:0.21063
# [73]	validation_0-error:0.05359	validation_1-error:0.20938
# [74]	validation_0-error:0.05250	validation_1-error:0.20938
# [75]	validation_0-error:0.04875	validation_1-error:0.21250
# [76]	validation_0-error:0.04875	validation_1-error:0.21125
# [77]	validation_0-error:0.04672	validation_1-error:0.21188
# [78]	validation_0-error:0.04656	validation_1-error:0.21188
# [79]	validation_0-error:0.04578	validation_1-error:0.21250
# [80]	validation_0-error:0.04453	validation_1-error:0.21125
# [81]	validation_0-error:0.04328	validation_1-error:0.21063
# [82]	validation_0-error:0.04250	validation_1-error:0.21000
# [83]	validation_0-error:0.04141	validation_1-error:0.21125
# [84]	validation_0-error:0.04125	validation_1-error:0.21188
# [85]	validation_0-error:0.04094	validation_1-error:0.21250
# [86]	validation_0-error:0.04000	validation_1-error:0.20938
# [87]	validation_0-error:0.03953	validation_1-error:0.20938
# [88]	validation_0-error:0.03891	validation_1-error:0.21000
# [89]	validation_0-error:0.03844	validation_1-error:0.20938
# [90]	validation_0-error:0.03641	validation_1-error:0.21438
# [91]	validation_0-error:0.03609	validation_1-error:0.21438
# [92]	validation_0-error:0.03547	validation_1-error:0.21375
# [93]	validation_0-error:0.03531	validation_1-error:0.21438
# [94]	validation_0-error:0.03438	validation_1-error:0.21188
# [95]	validation_0-error:0.03359	validation_1-error:0.21375
# [96]	validation_0-error:0.03313	validation_1-error:0.21313
# [97]	validation_0-error:0.03156	validation_1-error:0.21125
# [98]	validation_0-error:0.03109	validation_1-error:0.21000
# [99]	validation_0-error:0.02891	validation_1-error:0.21000
# [100]	validation_0-error:0.02875	validation_1-error:0.21000
# [101]	validation_0-error:0.02859	validation_1-error:0.20938
# [102]	validation_0-error:0.02813	validation_1-error:0.21063
# [103]	validation_0-error:0.02859	validation_1-error:0.21000
# [104]	validation_0-error:0.02875	validation_1-error:0.20938
# [105]	validation_0-error:0.02781	validation_1-error:0.21188
# [106]	validation_0-error:0.02750	validation_1-error:0.21125
# [107]	validation_0-error:0.02672	validation_1-error:0.21125
# [108]	validation_0-error:0.02641	validation_1-error:0.21250
# [109]	validation_0-error:0.02656	validation_1-error:0.21063
# [110]	validation_0-error:0.02547	validation_1-error:0.21000
# [111]	validation_0-error:0.02406	validation_1-error:0.21250
# [112]	validation_0-error:0.02297	validation_1-error:0.20938
# [113]	validation_0-error:0.02266	validation_1-error:0.21125
# [114]	validation_0-error:0.02250	validation_1-error:0.21250
# [115]	validation_0-error:0.02172	validation_1-error:0.21188
# [116]	validation_0-error:0.02125	validation_1-error:0.21375
# [117]	validation_0-error:0.01937	validation_1-error:0.21688
# [118]	validation_0-error:0.01812	validation_1-error:0.21625
# [119]	validation_0-error:0.01719	validation_1-error:0.21750
# [120]	validation_0-error:0.01656	validation_1-error:0.21438
# [121]	validation_0-error:0.01688	validation_1-error:0.21500
# [122]	validation_0-error:0.01578	validation_1-error:0.21625
# [123]	validation_0-error:0.01531	validation_1-error:0.21688
# [124]	validation_0-error:0.01547	validation_1-error:0.21563
# [125]	validation_0-error:0.01547	validation_1-error:0.21563
# [126]	validation_0-error:0.01516	validation_1-error:0.21625
# [127]	validation_0-error:0.01516	validation_1-error:0.22000
# [128]	validation_0-error:0.01469	validation_1-error:0.21813
# [129]	validation_0-error:0.01453	validation_1-error:0.21750
# [130]	validation_0-error:0.01469	validation_1-error:0.21937
# [131]	validation_0-error:0.01438	validation_1-error:0.22125
# [132]	validation_0-error:0.01438	validation_1-error:0.22000
# [133]	validation_0-error:0.01422	validation_1-error:0.21875
# [134]	validation_0-error:0.01438	validation_1-error:0.21875
# [135]	validation_0-error:0.01328	validation_1-error:0.21813
# [136]	validation_0-error:0.01266	validation_1-error:0.21500
# [137]	validation_0-error:0.01219	validation_1-error:0.21563
# [138]	validation_0-error:0.01203	validation_1-error:0.21563
# [139]	validation_0-error:0.01203	validation_1-error:0.21500
# [140]	validation_0-error:0.01188	validation_1-error:0.21688
# [141]	validation_0-error:0.01109	validation_1-error:0.21375
# [142]	validation_0-error:0.01094	validation_1-error:0.21313
# [143]	validation_0-error:0.01109	validation_1-error:0.21375
# [144]	validation_0-error:0.01094	validation_1-error:0.21313
# [145]	validation_0-error:0.01094	validation_1-error:0.21313
# [146]	validation_0-error:0.01109	validation_1-error:0.21313
# [147]	validation_0-error:0.01109	validation_1-error:0.21438
# [148]	validation_0-error:0.01109	validation_1-error:0.21563
# [149]	validation_0-error:0.01109	validation_1-error:0.21563
# [150]	validation_0-error:0.01031	validation_1-error:0.21688
# [151]	validation_0-error:0.01016	validation_1-error:0.21813
# [152]	validation_0-error:0.01016	validation_1-error:0.21813
# [153]	validation_0-error:0.01000	validation_1-error:0.21750
# [154]	validation_0-error:0.00953	validation_1-error:0.21625
# [155]	validation_0-error:0.01000	validation_1-error:0.21688
# [156]	validation_0-error:0.00922	validation_1-error:0.21563
# [157]	validation_0-error:0.00859	validation_1-error:0.21750
# [158]	validation_0-error:0.00781	validation_1-error:0.21625
# [159]	validation_0-error:0.00719	validation_1-error:0.21500
# [160]	validation_0-error:0.00656	validation_1-error:0.21500
# [161]	validation_0-error:0.00609	validation_1-error:0.21438
# [162]	validation_0-error:0.00609	validation_1-error:0.21500
# [163]	validation_0-error:0.00609	validation_1-error:0.21438
# [164]	validation_0-error:0.00562	validation_1-error:0.21625
# [165]	validation_0-error:0.00562	validation_1-error:0.21625
# [166]	validation_0-error:0.00531	validation_1-error:0.21813
# [167]	validation_0-error:0.00500	validation_1-error:0.21750
# [168]	validation_0-error:0.00484	validation_1-error:0.21688
# [169]	validation_0-error:0.00484	validation_1-error:0.21563
# [170]	validation_0-error:0.00484	validation_1-error:0.21625
# [171]	validation_0-error:0.00453	validation_1-error:0.21875
# [172]	validation_0-error:0.00438	validation_1-error:0.21813
# [173]	validation_0-error:0.00422	validation_1-error:0.21813
# [174]	validation_0-error:0.00422	validation_1-error:0.21750
# [175]	validation_0-error:0.00391	validation_1-error:0.21563
# [176]	validation_0-error:0.00391	validation_1-error:0.21625
# [177]	validation_0-error:0.00359	validation_1-error:0.21625
# [178]	validation_0-error:0.00313	validation_1-error:0.21688
# [179]	validation_0-error:0.00313	validation_1-error:0.21750
# [180]	validation_0-error:0.00281	validation_1-error:0.21750
# [181]	validation_0-error:0.00250	validation_1-error:0.21813
# [182]	validation_0-error:0.00250	validation_1-error:0.21813
# [183]	validation_0-error:0.00234	validation_1-error:0.21937
# [184]	validation_0-error:0.00219	validation_1-error:0.22062
# [185]	validation_0-error:0.00219	validation_1-error:0.22000
# [186]	validation_0-error:0.00219	validation_1-error:0.22187
# [187]	validation_0-error:0.00219	validation_1-error:0.22250
# [188]	validation_0-error:0.00187	validation_1-error:0.22375
# [189]	validation_0-error:0.00187	validation_1-error:0.22375
# [190]	validation_0-error:0.00156	validation_1-error:0.22250
# [191]	validation_0-error:0.00156	validation_1-error:0.22187
# [192]	validation_0-error:0.00156	validation_1-error:0.22500
# [193]	validation_0-error:0.00156	validation_1-error:0.22437
# [194]	validation_0-error:0.00156	validation_1-error:0.22312
# [195]	validation_0-error:0.00141	validation_1-error:0.22062
# [196]	validation_0-error:0.00125	validation_1-error:0.22187
# [197]	validation_0-error:0.00125	validation_1-error:0.22062
# [198]	validation_0-error:0.00109	validation_1-error:0.22250
# [199]	validation_0-error:0.00109	validation_1-error:0.22250
# [200]	validation_0-error:0.00094	validation_1-error:0.22250
# [201]	validation_0-error:0.00047	validation_1-error:0.22187
# [202]	validation_0-error:0.00063	validation_1-error:0.22000
# [203]	validation_0-error:0.00063	validation_1-error:0.22250
# [204]	validation_0-error:0.00063	validation_1-error:0.22125
# [205]	validation_0-error:0.00063	validation_1-error:0.22187
# [206]	validation_0-error:0.00063	validation_1-error:0.22187
# [207]	validation_0-error:0.00063	validation_1-error:0.22125
# [208]	validation_0-error:0.00078	validation_1-error:0.22375
# [209]	validation_0-error:0.00078	validation_1-error:0.22500
# [210]	validation_0-error:0.00078	validation_1-error:0.22375
# [211]	validation_0-error:0.00063	validation_1-error:0.22312
# [212]	validation_0-error:0.00047	validation_1-error:0.22500
# [213]	validation_0-error:0.00047	validation_1-error:0.22375
# [214]	validation_0-error:0.00047	validation_1-error:0.22250
# [215]	validation_0-error:0.00047	validation_1-error:0.22187
# [216]	validation_0-error:0.00047	validation_1-error:0.22125
# [217]	validation_0-error:0.00047	validation_1-error:0.22250
# [218]	validation_0-error:0.00047	validation_1-error:0.22312
# [219]	validation_0-error:0.00047	validation_1-error:0.22312
# [220]	validation_0-error:0.00047	validation_1-error:0.22250
# [221]	validation_0-error:0.00031	validation_1-error:0.22187
# [222]	validation_0-error:0.00016	validation_1-error:0.22250
# [223]	validation_0-error:0.00016	validation_1-error:0.22375
# [224]	validation_0-error:0.00016	validation_1-error:0.22250
# [225]	validation_0-error:0.00016	validation_1-error:0.22250
# [226]	validation_0-error:0.00016	validation_1-error:0.22125
# [227]	validation_0-error:0.00016	validation_1-error:0.21937
# [228]	validation_0-error:0.00031	validation_1-error:0.22062
# [229]	validation_0-error:0.00031	validation_1-error:0.22000
# [230]	validation_0-error:0.00031	validation_1-error:0.22062
# [231]	validation_0-error:0.00031	validation_1-error:0.22125
# [232]	validation_0-error:0.00031	validation_1-error:0.22125
# [233]	validation_0-error:0.00016	validation_1-error:0.22062
# [234]	validation_0-error:0.00000	validation_1-error:0.22187
# [235]	validation_0-error:0.00000	validation_1-error:0.22250
# [236]	validation_0-error:0.00000	validation_1-error:0.22187
# [237]	validation_0-error:0.00000	validation_1-error:0.22187
# [238]	validation_0-error:0.00000	validation_1-error:0.22062
# [239]	validation_0-error:0.00000	validation_1-error:0.22125
# [240]	validation_0-error:0.00000	validation_1-error:0.22250
# fold n°1
# trn_idx: [   0    1    2 ... 7997 7998 7999]
# val_idx: [  15   28   35 ... 7986 7993 7996]
# [0]	validation_0-error:0.21547	validation_1-error:0.23750
# [1]	validation_0-error:0.20516	validation_1-error:0.23125
# [2]	validation_0-error:0.19734	validation_1-error:0.21937
# [3]	validation_0-error:0.18953	validation_1-error:0.21750
# [4]	validation_0-error:0.18531	validation_1-error:0.22375
# [5]	validation_0-error:0.18172	validation_1-error:0.21563
# [6]	validation_0-error:0.17625	validation_1-error:0.21438
# [7]	validation_0-error:0.17172	validation_1-error:0.21375
# [8]	validation_0-error:0.16812	validation_1-error:0.21375
# [9]	validation_0-error:0.16437	validation_1-error:0.21313
# [10]	validation_0-error:0.16469	validation_1-error:0.21313
# [11]	validation_0-error:0.16016	validation_1-error:0.21563
# [12]	validation_0-error:0.15766	validation_1-error:0.21250
# [13]	validation_0-error:0.15687	validation_1-error:0.21375
# [14]	validation_0-error:0.15594	validation_1-error:0.21563
# [15]	validation_0-error:0.15234	validation_1-error:0.21625
# [16]	validation_0-error:0.15250	validation_1-error:0.21375
# [17]	validation_0-error:0.14906	validation_1-error:0.20938
# [18]	validation_0-error:0.14813	validation_1-error:0.20750
# [19]	validation_0-error:0.14594	validation_1-error:0.21313
# [20]	validation_0-error:0.14313	validation_1-error:0.21125
# [21]	validation_0-error:0.14016	validation_1-error:0.21250
# [22]	validation_0-error:0.13656	validation_1-error:0.21313
# [23]	validation_0-error:0.13422	validation_1-error:0.21125
# [24]	validation_0-error:0.13250	validation_1-error:0.21063
# [25]	validation_0-error:0.13062	validation_1-error:0.21000
# [26]	validation_0-error:0.12750	validation_1-error:0.21125
# [27]	validation_0-error:0.12594	validation_1-error:0.21188
# [28]	validation_0-error:0.12437	validation_1-error:0.21125
# [29]	validation_0-error:0.12437	validation_1-error:0.21063
# [30]	validation_0-error:0.12359	validation_1-error:0.21000
# [31]	validation_0-error:0.12109	validation_1-error:0.21250
# [32]	validation_0-error:0.11828	validation_1-error:0.21438
# [33]	validation_0-error:0.11500	validation_1-error:0.21313
# [34]	validation_0-error:0.11109	validation_1-error:0.20938
# [35]	validation_0-error:0.10922	validation_1-error:0.21000
# [36]	validation_0-error:0.10547	validation_1-error:0.20938
# [37]	validation_0-error:0.10422	validation_1-error:0.21125
# [38]	validation_0-error:0.10328	validation_1-error:0.21000
# [39]	validation_0-error:0.10281	validation_1-error:0.21188
# [40]	validation_0-error:0.10172	validation_1-error:0.21125
# [41]	validation_0-error:0.09828	validation_1-error:0.20813
# [42]	validation_0-error:0.09625	validation_1-error:0.20750
# [43]	validation_0-error:0.09563	validation_1-error:0.20813
# [44]	validation_0-error:0.09312	validation_1-error:0.21000
# [45]	validation_0-error:0.09266	validation_1-error:0.20938
# [46]	validation_0-error:0.09203	validation_1-error:0.20938
# [47]	validation_0-error:0.09109	validation_1-error:0.20875
# [48]	validation_0-error:0.09000	validation_1-error:0.20938
# [49]	validation_0-error:0.08906	validation_1-error:0.20938
# [50]	validation_0-error:0.08781	validation_1-error:0.21188
# [51]	validation_0-error:0.08609	validation_1-error:0.20938
# [52]	validation_0-error:0.08500	validation_1-error:0.21000
# [53]	validation_0-error:0.08188	validation_1-error:0.20875
# [54]	validation_0-error:0.08156	validation_1-error:0.20875
# [55]	validation_0-error:0.08047	validation_1-error:0.21063
# [56]	validation_0-error:0.08016	validation_1-error:0.21000
# [57]	validation_0-error:0.07953	validation_1-error:0.21063
# [58]	validation_0-error:0.07891	validation_1-error:0.20813
# [59]	validation_0-error:0.07656	validation_1-error:0.20875
# [60]	validation_0-error:0.07437	validation_1-error:0.20563
# [61]	validation_0-error:0.07312	validation_1-error:0.20625
# [62]	validation_0-error:0.07094	validation_1-error:0.20438
# [63]	validation_0-error:0.07062	validation_1-error:0.20563
# [64]	validation_0-error:0.06766	validation_1-error:0.20625
# [65]	validation_0-error:0.06594	validation_1-error:0.20813
# [66]	validation_0-error:0.06469	validation_1-error:0.20625
# [67]	validation_0-error:0.06359	validation_1-error:0.20438
# [68]	validation_0-error:0.06266	validation_1-error:0.20563
# [69]	validation_0-error:0.06094	validation_1-error:0.20250
# [70]	validation_0-error:0.06016	validation_1-error:0.20563
# [71]	validation_0-error:0.05922	validation_1-error:0.20500
# [72]	validation_0-error:0.05688	validation_1-error:0.20438
# [73]	validation_0-error:0.05656	validation_1-error:0.20563
# [74]	validation_0-error:0.05484	validation_1-error:0.20563
# [75]	validation_0-error:0.05203	validation_1-error:0.20625
# [76]	validation_0-error:0.05078	validation_1-error:0.20312
# [77]	validation_0-error:0.04891	validation_1-error:0.20438
# [78]	validation_0-error:0.04859	validation_1-error:0.20625
# [79]	validation_0-error:0.04797	validation_1-error:0.20563
# [80]	validation_0-error:0.04578	validation_1-error:0.20438
# [81]	validation_0-error:0.04453	validation_1-error:0.20625
# [82]	validation_0-error:0.04359	validation_1-error:0.20500
# [83]	validation_0-error:0.04312	validation_1-error:0.20250
# [84]	validation_0-error:0.04266	validation_1-error:0.20187
# [85]	validation_0-error:0.04219	validation_1-error:0.20062
# [86]	validation_0-error:0.04078	validation_1-error:0.20062
# [87]	validation_0-error:0.04078	validation_1-error:0.20125
# [88]	validation_0-error:0.04000	validation_1-error:0.20062
# [89]	validation_0-error:0.03938	validation_1-error:0.20062
# [90]	validation_0-error:0.03938	validation_1-error:0.20000
# [91]	validation_0-error:0.03922	validation_1-error:0.20125
# [92]	validation_0-error:0.03891	validation_1-error:0.20187
# [93]	validation_0-error:0.03812	validation_1-error:0.20563
# [94]	validation_0-error:0.03828	validation_1-error:0.20563
# [95]	validation_0-error:0.03719	validation_1-error:0.20813
# [96]	validation_0-error:0.03469	validation_1-error:0.21063
# [97]	validation_0-error:0.03484	validation_1-error:0.21063
# [98]	validation_0-error:0.03422	validation_1-error:0.20875
# [99]	validation_0-error:0.03375	validation_1-error:0.20625
# [100]	validation_0-error:0.03391	validation_1-error:0.20750
# [101]	validation_0-error:0.03406	validation_1-error:0.20625
# [102]	validation_0-error:0.03203	validation_1-error:0.20625
# [103]	validation_0-error:0.03078	validation_1-error:0.20688
# [104]	validation_0-error:0.02844	validation_1-error:0.20438
# [105]	validation_0-error:0.02687	validation_1-error:0.20438
# [106]	validation_0-error:0.02609	validation_1-error:0.20625
# [107]	validation_0-error:0.02594	validation_1-error:0.20625
# [108]	validation_0-error:0.02516	validation_1-error:0.20625
# [109]	validation_0-error:0.02484	validation_1-error:0.20625
# [110]	validation_0-error:0.02312	validation_1-error:0.20750
# [111]	validation_0-error:0.02141	validation_1-error:0.20750
# [112]	validation_0-error:0.02094	validation_1-error:0.20750
# [113]	validation_0-error:0.01937	validation_1-error:0.20875
# [114]	validation_0-error:0.01937	validation_1-error:0.21000
# [115]	validation_0-error:0.01906	validation_1-error:0.21000
# [116]	validation_0-error:0.01859	validation_1-error:0.20813
# [117]	validation_0-error:0.01812	validation_1-error:0.21000
# [118]	validation_0-error:0.01734	validation_1-error:0.21125
# [119]	validation_0-error:0.01703	validation_1-error:0.21188
# [120]	validation_0-error:0.01688	validation_1-error:0.21125
# [121]	validation_0-error:0.01672	validation_1-error:0.21188
# [122]	validation_0-error:0.01672	validation_1-error:0.21000
# [123]	validation_0-error:0.01672	validation_1-error:0.21063
# [124]	validation_0-error:0.01672	validation_1-error:0.21000
# [125]	validation_0-error:0.01516	validation_1-error:0.21188
# [126]	validation_0-error:0.01516	validation_1-error:0.21250
# [127]	validation_0-error:0.01500	validation_1-error:0.21250
# [128]	validation_0-error:0.01516	validation_1-error:0.21250
# [129]	validation_0-error:0.01406	validation_1-error:0.21125
# [130]	validation_0-error:0.01359	validation_1-error:0.21125
# [131]	validation_0-error:0.01328	validation_1-error:0.21188
# [132]	validation_0-error:0.01281	validation_1-error:0.21188
# [133]	validation_0-error:0.01297	validation_1-error:0.21313
# [134]	validation_0-error:0.01297	validation_1-error:0.21250
# [135]	validation_0-error:0.01297	validation_1-error:0.21250
# [136]	validation_0-error:0.01219	validation_1-error:0.21063
# [137]	validation_0-error:0.01203	validation_1-error:0.21125
# [138]	validation_0-error:0.01047	validation_1-error:0.20938
# [139]	validation_0-error:0.01047	validation_1-error:0.20938
# [140]	validation_0-error:0.01031	validation_1-error:0.21188
# [141]	validation_0-error:0.00984	validation_1-error:0.21125
# [142]	validation_0-error:0.00969	validation_1-error:0.21313
# [143]	validation_0-error:0.00922	validation_1-error:0.21375
# [144]	validation_0-error:0.00891	validation_1-error:0.21250
# [145]	validation_0-error:0.00781	validation_1-error:0.21000
# [146]	validation_0-error:0.00781	validation_1-error:0.21188
# [147]	validation_0-error:0.00766	validation_1-error:0.21188
# [148]	validation_0-error:0.00766	validation_1-error:0.21125
# [149]	validation_0-error:0.00750	validation_1-error:0.21125
# [150]	validation_0-error:0.00734	validation_1-error:0.20938
# [151]	validation_0-error:0.00734	validation_1-error:0.20938
# [152]	validation_0-error:0.00719	validation_1-error:0.20938
# [153]	validation_0-error:0.00719	validation_1-error:0.21063
# [154]	validation_0-error:0.00625	validation_1-error:0.20938
# [155]	validation_0-error:0.00641	validation_1-error:0.21125
# [156]	validation_0-error:0.00641	validation_1-error:0.21125
# [157]	validation_0-error:0.00609	validation_1-error:0.21063
# [158]	validation_0-error:0.00609	validation_1-error:0.21000
# [159]	validation_0-error:0.00547	validation_1-error:0.21000
# [160]	validation_0-error:0.00500	validation_1-error:0.21063
# [161]	validation_0-error:0.00500	validation_1-error:0.21125
# [162]	validation_0-error:0.00500	validation_1-error:0.21125
# [163]	validation_0-error:0.00469	validation_1-error:0.21188
# [164]	validation_0-error:0.00453	validation_1-error:0.21063
# [165]	validation_0-error:0.00438	validation_1-error:0.20938
# [166]	validation_0-error:0.00422	validation_1-error:0.20750
# [167]	validation_0-error:0.00375	validation_1-error:0.20750
# [168]	validation_0-error:0.00375	validation_1-error:0.20688
# [169]	validation_0-error:0.00375	validation_1-error:0.20750
# [170]	validation_0-error:0.00375	validation_1-error:0.20750
# [171]	validation_0-error:0.00375	validation_1-error:0.20688
# [172]	validation_0-error:0.00375	validation_1-error:0.20750
# [173]	validation_0-error:0.00375	validation_1-error:0.20688
# [174]	validation_0-error:0.00375	validation_1-error:0.20938
# [175]	validation_0-error:0.00375	validation_1-error:0.20813
# [176]	validation_0-error:0.00344	validation_1-error:0.20938
# [177]	validation_0-error:0.00297	validation_1-error:0.20750
# [178]	validation_0-error:0.00281	validation_1-error:0.21000
# [179]	validation_0-error:0.00281	validation_1-error:0.21000
# [180]	validation_0-error:0.00266	validation_1-error:0.21125
# [181]	validation_0-error:0.00266	validation_1-error:0.21125
# [182]	validation_0-error:0.00219	validation_1-error:0.21250
# [183]	validation_0-error:0.00203	validation_1-error:0.21125
# [184]	validation_0-error:0.00203	validation_1-error:0.21188
# [185]	validation_0-error:0.00203	validation_1-error:0.21188
# [186]	validation_0-error:0.00203	validation_1-error:0.21063
# [187]	validation_0-error:0.00203	validation_1-error:0.20875
# [188]	validation_0-error:0.00203	validation_1-error:0.21000
# [189]	validation_0-error:0.00203	validation_1-error:0.21000
# [190]	validation_0-error:0.00203	validation_1-error:0.21000
# [191]	validation_0-error:0.00203	validation_1-error:0.21063
# [192]	validation_0-error:0.00203	validation_1-error:0.21000
# [193]	validation_0-error:0.00203	validation_1-error:0.20813
# [194]	validation_0-error:0.00172	validation_1-error:0.20813
# [195]	validation_0-error:0.00172	validation_1-error:0.20875
# [196]	validation_0-error:0.00187	validation_1-error:0.20938
# [197]	validation_0-error:0.00187	validation_1-error:0.21063
# [198]	validation_0-error:0.00156	validation_1-error:0.21063
# [199]	validation_0-error:0.00141	validation_1-error:0.21063
# [200]	validation_0-error:0.00141	validation_1-error:0.21125
# [201]	validation_0-error:0.00156	validation_1-error:0.21000
# [202]	validation_0-error:0.00156	validation_1-error:0.20938
# [203]	validation_0-error:0.00156	validation_1-error:0.20938
# [204]	validation_0-error:0.00156	validation_1-error:0.20938
# [205]	validation_0-error:0.00109	validation_1-error:0.20938
# [206]	validation_0-error:0.00125	validation_1-error:0.21000
# [207]	validation_0-error:0.00125	validation_1-error:0.20938
# [208]	validation_0-error:0.00109	validation_1-error:0.20625
# [209]	validation_0-error:0.00094	validation_1-error:0.20875
# [210]	validation_0-error:0.00109	validation_1-error:0.20875
# [211]	validation_0-error:0.00109	validation_1-error:0.20938
# [212]	validation_0-error:0.00109	validation_1-error:0.20688
# [213]	validation_0-error:0.00109	validation_1-error:0.20750
# [214]	validation_0-error:0.00109	validation_1-error:0.20625
# [215]	validation_0-error:0.00141	validation_1-error:0.20813
# [216]	validation_0-error:0.00109	validation_1-error:0.20688
# [217]	validation_0-error:0.00109	validation_1-error:0.20688
# [218]	validation_0-error:0.00109	validation_1-error:0.20688
# [219]	validation_0-error:0.00109	validation_1-error:0.20688
# [220]	validation_0-error:0.00078	validation_1-error:0.20875
# [221]	validation_0-error:0.00094	validation_1-error:0.20813
# [222]	validation_0-error:0.00094	validation_1-error:0.20938
# [223]	validation_0-error:0.00094	validation_1-error:0.21000
# [224]	validation_0-error:0.00094	validation_1-error:0.21000
# [225]	validation_0-error:0.00094	validation_1-error:0.20938
# [226]	validation_0-error:0.00078	validation_1-error:0.20938
# [227]	validation_0-error:0.00078	validation_1-error:0.21000
# [228]	validation_0-error:0.00031	validation_1-error:0.21000
# [229]	validation_0-error:0.00047	validation_1-error:0.21000
# [230]	validation_0-error:0.00047	validation_1-error:0.21000
# [231]	validation_0-error:0.00031	validation_1-error:0.21000
# [232]	validation_0-error:0.00047	validation_1-error:0.21188
# [233]	validation_0-error:0.00047	validation_1-error:0.21250
# [234]	validation_0-error:0.00047	validation_1-error:0.21313
# [235]	validation_0-error:0.00047	validation_1-error:0.21313
# [236]	validation_0-error:0.00047	validation_1-error:0.21313
# [237]	validation_0-error:0.00047	validation_1-error:0.21250
# [238]	validation_0-error:0.00031	validation_1-error:0.21125
# [239]	validation_0-error:0.00031	validation_1-error:0.21063
# [240]	validation_0-error:0.00016	validation_1-error:0.20875
# [241]	validation_0-error:0.00016	validation_1-error:0.20875
# [242]	validation_0-error:0.00016	validation_1-error:0.21000
# [243]	validation_0-error:0.00031	validation_1-error:0.21063
# [244]	validation_0-error:0.00031	validation_1-error:0.20938
# [245]	validation_0-error:0.00031	validation_1-error:0.20938
# [246]	validation_0-error:0.00031	validation_1-error:0.21000
# [247]	validation_0-error:0.00016	validation_1-error:0.21000
# [248]	validation_0-error:0.00031	validation_1-error:0.21000
# [249]	validation_0-error:0.00031	validation_1-error:0.21000
# [250]	validation_0-error:0.00031	validation_1-error:0.21063
# [251]	validation_0-error:0.00016	validation_1-error:0.21188
# [252]	validation_0-error:0.00016	validation_1-error:0.21125
# [253]	validation_0-error:0.00031	validation_1-error:0.21250
# [254]	validation_0-error:0.00031	validation_1-error:0.21125
# [255]	validation_0-error:0.00031	validation_1-error:0.21063
# [256]	validation_0-error:0.00031	validation_1-error:0.21125
# [257]	validation_0-error:0.00031	validation_1-error:0.21375
# [258]	validation_0-error:0.00031	validation_1-error:0.21313
# [259]	validation_0-error:0.00000	validation_1-error:0.21188
# [260]	validation_0-error:0.00016	validation_1-error:0.21188
# [261]	validation_0-error:0.00000	validation_1-error:0.21188
# [262]	validation_0-error:0.00000	validation_1-error:0.21250
# [263]	validation_0-error:0.00000	validation_1-error:0.21188
# [264]	validation_0-error:0.00000	validation_1-error:0.21063
# [265]	validation_0-error:0.00000	validation_1-error:0.21063
# [266]	validation_0-error:0.00000	validation_1-error:0.21000
# [267]	validation_0-error:0.00000	validation_1-error:0.21063
# [268]	validation_0-error:0.00000	validation_1-error:0.21125
# [269]	validation_0-error:0.00000	validation_1-error:0.21125
# [270]	validation_0-error:0.00000	validation_1-error:0.21125
# [271]	validation_0-error:0.00000	validation_1-error:0.21063
# [272]	validation_0-error:0.00000	validation_1-error:0.21125
# [273]	validation_0-error:0.00000	validation_1-error:0.21000
# [274]	validation_0-error:0.00000	validation_1-error:0.21063
# [275]	validation_0-error:0.00000	validation_1-error:0.20875
# [276]	validation_0-error:0.00000	validation_1-error:0.20750
# [277]	validation_0-error:0.00000	validation_1-error:0.20813
# [278]	validation_0-error:0.00000	validation_1-error:0.20813
# [279]	validation_0-error:0.00000	validation_1-error:0.20750
# [280]	validation_0-error:0.00000	validation_1-error:0.20938
# [281]	validation_0-error:0.00000	validation_1-error:0.20750
# [282]	validation_0-error:0.00000	validation_1-error:0.21000
# [283]	validation_0-error:0.00000	validation_1-error:0.20875
# [284]	validation_0-error:0.00000	validation_1-error:0.20938
# [285]	validation_0-error:0.00000	validation_1-error:0.20625
# [286]	validation_0-error:0.00000	validation_1-error:0.20813
# [287]	validation_0-error:0.00000	validation_1-error:0.20875
# [288]	validation_0-error:0.00000	validation_1-error:0.20875
# [289]	validation_0-error:0.00000	validation_1-error:0.21000
# fold n°2
# trn_idx: [   0    1    2 ... 7997 7998 7999]
# val_idx: [   3    4   14 ... 7977 7978 7994]
# [0]	validation_0-error:0.21656	validation_1-error:0.23062
# [1]	validation_0-error:0.20281	validation_1-error:0.21813
# [2]	validation_0-error:0.19844	validation_1-error:0.21563
# [3]	validation_0-error:0.19203	validation_1-error:0.21125
# [4]	validation_0-error:0.18344	validation_1-error:0.20438
# [5]	validation_0-error:0.17891	validation_1-error:0.19437
# [6]	validation_0-error:0.17406	validation_1-error:0.19687
# [7]	validation_0-error:0.17016	validation_1-error:0.19500
# [8]	validation_0-error:0.16719	validation_1-error:0.19812
# [9]	validation_0-error:0.16625	validation_1-error:0.19562
# [10]	validation_0-error:0.16500	validation_1-error:0.19625
# [11]	validation_0-error:0.16016	validation_1-error:0.19375
# [12]	validation_0-error:0.15969	validation_1-error:0.19312
# [13]	validation_0-error:0.15609	validation_1-error:0.19125
# [14]	validation_0-error:0.15281	validation_1-error:0.18875
# [15]	validation_0-error:0.14797	validation_1-error:0.18875
# [16]	validation_0-error:0.14609	validation_1-error:0.19000
# [17]	validation_0-error:0.14422	validation_1-error:0.19062
# [18]	validation_0-error:0.14297	validation_1-error:0.18812
# [19]	validation_0-error:0.14125	validation_1-error:0.18812
# [20]	validation_0-error:0.13875	validation_1-error:0.19000
# [21]	validation_0-error:0.13828	validation_1-error:0.18812
# [22]	validation_0-error:0.13547	validation_1-error:0.18812
# [23]	validation_0-error:0.13500	validation_1-error:0.18812
# [24]	validation_0-error:0.13375	validation_1-error:0.18750
# [25]	validation_0-error:0.13297	validation_1-error:0.18812
# [26]	validation_0-error:0.13187	validation_1-error:0.18812
# [27]	validation_0-error:0.13156	validation_1-error:0.18875
# [28]	validation_0-error:0.12922	validation_1-error:0.18625
# [29]	validation_0-error:0.12625	validation_1-error:0.18875
# [30]	validation_0-error:0.12562	validation_1-error:0.18937
# [31]	validation_0-error:0.12469	validation_1-error:0.18937
# [32]	validation_0-error:0.12375	validation_1-error:0.19062
# [33]	validation_0-error:0.11937	validation_1-error:0.18875
# [34]	validation_0-error:0.11547	validation_1-error:0.18750
# [35]	validation_0-error:0.11266	validation_1-error:0.19062
# [36]	validation_0-error:0.11141	validation_1-error:0.18688
# [37]	validation_0-error:0.11063	validation_1-error:0.18750
# [38]	validation_0-error:0.10891	validation_1-error:0.18688
# [39]	validation_0-error:0.10734	validation_1-error:0.18688
# [40]	validation_0-error:0.10391	validation_1-error:0.18937
# [41]	validation_0-error:0.10344	validation_1-error:0.19125
# [42]	validation_0-error:0.10141	validation_1-error:0.19187
# [43]	validation_0-error:0.10109	validation_1-error:0.19187
# [44]	validation_0-error:0.10094	validation_1-error:0.19000
# [45]	validation_0-error:0.09859	validation_1-error:0.19000
# [46]	validation_0-error:0.09578	validation_1-error:0.19437
# [47]	validation_0-error:0.09125	validation_1-error:0.19375
# [48]	validation_0-error:0.08969	validation_1-error:0.19375
# [49]	validation_0-error:0.08953	validation_1-error:0.19375
# [50]	validation_0-error:0.08719	validation_1-error:0.19437
# [51]	validation_0-error:0.08453	validation_1-error:0.19437
# [52]	validation_0-error:0.08391	validation_1-error:0.19375
# [53]	validation_0-error:0.08328	validation_1-error:0.19187
# [54]	validation_0-error:0.08203	validation_1-error:0.19250
# [55]	validation_0-error:0.08109	validation_1-error:0.19250
# [56]	validation_0-error:0.07609	validation_1-error:0.19312
# [57]	validation_0-error:0.07516	validation_1-error:0.19312
# [58]	validation_0-error:0.07375	validation_1-error:0.19437
# [59]	validation_0-error:0.07187	validation_1-error:0.19562
# [60]	validation_0-error:0.07156	validation_1-error:0.19562
# [61]	validation_0-error:0.07156	validation_1-error:0.19625
# [62]	validation_0-error:0.07141	validation_1-error:0.19625
# [63]	validation_0-error:0.07000	validation_1-error:0.19750
# [64]	validation_0-error:0.06969	validation_1-error:0.19687
# [65]	validation_0-error:0.06813	validation_1-error:0.19750
# [66]	validation_0-error:0.06563	validation_1-error:0.19312
# [67]	validation_0-error:0.06547	validation_1-error:0.19500
# [68]	validation_0-error:0.06266	validation_1-error:0.19625
# [69]	validation_0-error:0.06094	validation_1-error:0.19687
# [70]	validation_0-error:0.06062	validation_1-error:0.19812
# [71]	validation_0-error:0.06047	validation_1-error:0.19875
# [72]	validation_0-error:0.06047	validation_1-error:0.19875
# [73]	validation_0-error:0.05594	validation_1-error:0.20062
# [74]	validation_0-error:0.05422	validation_1-error:0.20187
# [75]	validation_0-error:0.05312	validation_1-error:0.20062
# [76]	validation_0-error:0.05047	validation_1-error:0.19937
# [77]	validation_0-error:0.04813	validation_1-error:0.20062
# [78]	validation_0-error:0.04766	validation_1-error:0.20250
# [79]	validation_0-error:0.04484	validation_1-error:0.20500
# [80]	validation_0-error:0.04391	validation_1-error:0.20438
# [81]	validation_0-error:0.04172	validation_1-error:0.20500
# [82]	validation_0-error:0.04125	validation_1-error:0.20500
# [83]	validation_0-error:0.04109	validation_1-error:0.20438
# [84]	validation_0-error:0.04094	validation_1-error:0.20500
# [85]	validation_0-error:0.04016	validation_1-error:0.20813
# [86]	validation_0-error:0.04016	validation_1-error:0.20625
# [87]	validation_0-error:0.03844	validation_1-error:0.20563
# [88]	validation_0-error:0.03844	validation_1-error:0.20563
# [89]	validation_0-error:0.03797	validation_1-error:0.20563
# [90]	validation_0-error:0.03750	validation_1-error:0.20500
# [91]	validation_0-error:0.03734	validation_1-error:0.20500
# [92]	validation_0-error:0.03750	validation_1-error:0.20312
# [93]	validation_0-error:0.03672	validation_1-error:0.20250
# [94]	validation_0-error:0.03687	validation_1-error:0.20375
# [95]	validation_0-error:0.03469	validation_1-error:0.20438
# [96]	validation_0-error:0.03406	validation_1-error:0.20312
# [97]	validation_0-error:0.03266	validation_1-error:0.20500
# [98]	validation_0-error:0.03219	validation_1-error:0.20438
# [99]	validation_0-error:0.03188	validation_1-error:0.20563
# [100]	validation_0-error:0.03141	validation_1-error:0.20688
# [101]	validation_0-error:0.03141	validation_1-error:0.20813
# [102]	validation_0-error:0.03078	validation_1-error:0.20750
# [103]	validation_0-error:0.02937	validation_1-error:0.20500
# [104]	validation_0-error:0.02891	validation_1-error:0.20500
# [105]	validation_0-error:0.02719	validation_1-error:0.20875
# [106]	validation_0-error:0.02719	validation_1-error:0.20938
# [107]	validation_0-error:0.02750	validation_1-error:0.20813
# [108]	validation_0-error:0.02734	validation_1-error:0.20750
# [109]	validation_0-error:0.02734	validation_1-error:0.20750
# [110]	validation_0-error:0.02562	validation_1-error:0.20750
# [111]	validation_0-error:0.02406	validation_1-error:0.20625
# [112]	validation_0-error:0.02375	validation_1-error:0.20625
# [113]	validation_0-error:0.02344	validation_1-error:0.20750
# [114]	validation_0-error:0.02297	validation_1-error:0.20750
# [115]	validation_0-error:0.02266	validation_1-error:0.20875
# [116]	validation_0-error:0.02281	validation_1-error:0.20875
# [117]	validation_0-error:0.02281	validation_1-error:0.20688
# [118]	validation_0-error:0.02141	validation_1-error:0.21063
# [119]	validation_0-error:0.02109	validation_1-error:0.21125
# [120]	validation_0-error:0.02000	validation_1-error:0.21063
# [121]	validation_0-error:0.01953	validation_1-error:0.21000
# [122]	validation_0-error:0.01953	validation_1-error:0.21125
# [123]	validation_0-error:0.01906	validation_1-error:0.21250
# [124]	validation_0-error:0.01891	validation_1-error:0.21375
# [125]	validation_0-error:0.01891	validation_1-error:0.21188
# [126]	validation_0-error:0.01891	validation_1-error:0.21125
# [127]	validation_0-error:0.01859	validation_1-error:0.20875
# [128]	validation_0-error:0.01719	validation_1-error:0.20813
# [129]	validation_0-error:0.01641	validation_1-error:0.20938
# [130]	validation_0-error:0.01641	validation_1-error:0.21063
# [131]	validation_0-error:0.01609	validation_1-error:0.21000
# [132]	validation_0-error:0.01594	validation_1-error:0.21000
# [133]	validation_0-error:0.01594	validation_1-error:0.20875
# [134]	validation_0-error:0.01469	validation_1-error:0.20813
# [135]	validation_0-error:0.01469	validation_1-error:0.20750
# [136]	validation_0-error:0.01406	validation_1-error:0.20750
# [137]	validation_0-error:0.01359	validation_1-error:0.20500
# [138]	validation_0-error:0.01297	validation_1-error:0.20500
# [139]	validation_0-error:0.01250	validation_1-error:0.20312
# [140]	validation_0-error:0.01188	validation_1-error:0.20375
# [141]	validation_0-error:0.01109	validation_1-error:0.20625
# [142]	validation_0-error:0.00969	validation_1-error:0.20625
# [143]	validation_0-error:0.00875	validation_1-error:0.20375
# [144]	validation_0-error:0.00828	validation_1-error:0.20438
# [145]	validation_0-error:0.00813	validation_1-error:0.20375
# [146]	validation_0-error:0.00781	validation_1-error:0.20500
# [147]	validation_0-error:0.00750	validation_1-error:0.20563
# [148]	validation_0-error:0.00734	validation_1-error:0.20625
# [149]	validation_0-error:0.00719	validation_1-error:0.20500
# [150]	validation_0-error:0.00609	validation_1-error:0.20500
# [151]	validation_0-error:0.00562	validation_1-error:0.20250
# [152]	validation_0-error:0.00562	validation_1-error:0.20375
# [153]	validation_0-error:0.00562	validation_1-error:0.20438
# [154]	validation_0-error:0.00547	validation_1-error:0.20563
# [155]	validation_0-error:0.00531	validation_1-error:0.20563
# [156]	validation_0-error:0.00438	validation_1-error:0.20312
# [157]	validation_0-error:0.00438	validation_1-error:0.20500
# [158]	validation_0-error:0.00438	validation_1-error:0.20438
# [159]	validation_0-error:0.00422	validation_1-error:0.20500
# [160]	validation_0-error:0.00422	validation_1-error:0.20500
# [161]	validation_0-error:0.00422	validation_1-error:0.20438
# [162]	validation_0-error:0.00438	validation_1-error:0.20563
# [163]	validation_0-error:0.00406	validation_1-error:0.20500
# [164]	validation_0-error:0.00406	validation_1-error:0.20375
# [165]	validation_0-error:0.00375	validation_1-error:0.20563
# [166]	validation_0-error:0.00375	validation_1-error:0.20563
# [167]	validation_0-error:0.00375	validation_1-error:0.20500
# [168]	validation_0-error:0.00313	validation_1-error:0.20625
# [169]	validation_0-error:0.00313	validation_1-error:0.20750
# [170]	validation_0-error:0.00313	validation_1-error:0.20938
# [171]	validation_0-error:0.00313	validation_1-error:0.20938
# [172]	validation_0-error:0.00313	validation_1-error:0.20875
# [173]	validation_0-error:0.00281	validation_1-error:0.21063
# [174]	validation_0-error:0.00281	validation_1-error:0.21063
# [175]	validation_0-error:0.00234	validation_1-error:0.21125
# [176]	validation_0-error:0.00250	validation_1-error:0.20875
# [177]	validation_0-error:0.00187	validation_1-error:0.20875
# [178]	validation_0-error:0.00203	validation_1-error:0.20875
# [179]	validation_0-error:0.00172	validation_1-error:0.20875
# [180]	validation_0-error:0.00172	validation_1-error:0.21125
# [181]	validation_0-error:0.00156	validation_1-error:0.21125
# [182]	validation_0-error:0.00125	validation_1-error:0.21188
# [183]	validation_0-error:0.00141	validation_1-error:0.21125
# [184]	validation_0-error:0.00156	validation_1-error:0.21063
# [185]	validation_0-error:0.00141	validation_1-error:0.21000
# [186]	validation_0-error:0.00141	validation_1-error:0.20938
# [187]	validation_0-error:0.00141	validation_1-error:0.21000
# [188]	validation_0-error:0.00141	validation_1-error:0.20813
# [189]	validation_0-error:0.00125	validation_1-error:0.20813
# [190]	validation_0-error:0.00109	validation_1-error:0.20875
# [191]	validation_0-error:0.00109	validation_1-error:0.20875
# [192]	validation_0-error:0.00109	validation_1-error:0.20875
# [193]	validation_0-error:0.00094	validation_1-error:0.20938
# [194]	validation_0-error:0.00094	validation_1-error:0.20875
# [195]	validation_0-error:0.00109	validation_1-error:0.20875
# [196]	validation_0-error:0.00109	validation_1-error:0.20813
# [197]	validation_0-error:0.00094	validation_1-error:0.20563
# [198]	validation_0-error:0.00109	validation_1-error:0.20813
# [199]	validation_0-error:0.00109	validation_1-error:0.20625
# [200]	validation_0-error:0.00094	validation_1-error:0.20813
# [201]	validation_0-error:0.00094	validation_1-error:0.20750
# [202]	validation_0-error:0.00094	validation_1-error:0.20563
# [203]	validation_0-error:0.00094	validation_1-error:0.20625
# [204]	validation_0-error:0.00094	validation_1-error:0.20813
# [205]	validation_0-error:0.00109	validation_1-error:0.20813
# [206]	validation_0-error:0.00109	validation_1-error:0.20750
# [207]	validation_0-error:0.00109	validation_1-error:0.20813
# [208]	validation_0-error:0.00094	validation_1-error:0.20875
# [209]	validation_0-error:0.00078	validation_1-error:0.21125
# [210]	validation_0-error:0.00063	validation_1-error:0.21188
# [211]	validation_0-error:0.00063	validation_1-error:0.21250
# [212]	validation_0-error:0.00063	validation_1-error:0.21250
# [213]	validation_0-error:0.00078	validation_1-error:0.21125
# [214]	validation_0-error:0.00063	validation_1-error:0.21250
# [215]	validation_0-error:0.00063	validation_1-error:0.21250
# [216]	validation_0-error:0.00063	validation_1-error:0.21375
# [217]	validation_0-error:0.00063	validation_1-error:0.21563
# [218]	validation_0-error:0.00063	validation_1-error:0.21500
# [219]	validation_0-error:0.00063	validation_1-error:0.21313
# [220]	validation_0-error:0.00047	validation_1-error:0.21313
# [221]	validation_0-error:0.00047	validation_1-error:0.21313
# [222]	validation_0-error:0.00047	validation_1-error:0.21313
# [223]	validation_0-error:0.00063	validation_1-error:0.21438
# [224]	validation_0-error:0.00031	validation_1-error:0.21313
# [225]	validation_0-error:0.00016	validation_1-error:0.21500
# [226]	validation_0-error:0.00016	validation_1-error:0.21625
# [227]	validation_0-error:0.00016	validation_1-error:0.21563
# [228]	validation_0-error:0.00016	validation_1-error:0.21625
# fold n°3
# trn_idx: [   0    1    3 ... 7995 7996 7999]
# val_idx: [   2    6    8 ... 7992 7997 7998]
# [0]	validation_0-error:0.20828	validation_1-error:0.25000
# [1]	validation_0-error:0.20187	validation_1-error:0.23375
# [2]	validation_0-error:0.19281	validation_1-error:0.23250
# [3]	validation_0-error:0.18906	validation_1-error:0.22625
# [4]	validation_0-error:0.18141	validation_1-error:0.22375
# [5]	validation_0-error:0.17656	validation_1-error:0.22062
# [6]	validation_0-error:0.17234	validation_1-error:0.22000
# [7]	validation_0-error:0.16875	validation_1-error:0.21813
# [8]	validation_0-error:0.16703	validation_1-error:0.21625
# [9]	validation_0-error:0.16328	validation_1-error:0.21750
# [10]	validation_0-error:0.16016	validation_1-error:0.21688
# [11]	validation_0-error:0.15594	validation_1-error:0.21188
# [12]	validation_0-error:0.15375	validation_1-error:0.21125
# [13]	validation_0-error:0.15438	validation_1-error:0.21125
# [14]	validation_0-error:0.15141	validation_1-error:0.21313
# [15]	validation_0-error:0.14766	validation_1-error:0.21125
# [16]	validation_0-error:0.14672	validation_1-error:0.21313
# [17]	validation_0-error:0.14531	validation_1-error:0.21313
# [18]	validation_0-error:0.14156	validation_1-error:0.21063
# [19]	validation_0-error:0.13875	validation_1-error:0.20938
# [20]	validation_0-error:0.13344	validation_1-error:0.20750
# [21]	validation_0-error:0.13109	validation_1-error:0.21000
# [22]	validation_0-error:0.12562	validation_1-error:0.21250
# [23]	validation_0-error:0.12609	validation_1-error:0.21188
# [24]	validation_0-error:0.12516	validation_1-error:0.21188
# [25]	validation_0-error:0.12328	validation_1-error:0.21188
# [26]	validation_0-error:0.12266	validation_1-error:0.21313
# [27]	validation_0-error:0.12109	validation_1-error:0.21375
# [28]	validation_0-error:0.11688	validation_1-error:0.21313
# [29]	validation_0-error:0.11531	validation_1-error:0.21250
# [30]	validation_0-error:0.11375	validation_1-error:0.21375
# [31]	validation_0-error:0.11109	validation_1-error:0.21063
# [32]	validation_0-error:0.10672	validation_1-error:0.20938
# [33]	validation_0-error:0.10484	validation_1-error:0.21125
# [34]	validation_0-error:0.10250	validation_1-error:0.21125
# [35]	validation_0-error:0.10281	validation_1-error:0.21188
# [36]	validation_0-error:0.10125	validation_1-error:0.21000
# [37]	validation_0-error:0.09828	validation_1-error:0.21125
# [38]	validation_0-error:0.09609	validation_1-error:0.21063
# ...
# [3]	validation_0-error:0.18812	validation_1-error:0.21438
# [4]	validation_0-error:0.18469	validation_1-error:0.21625
# [5]	validation_0-error:0.18031	validation_1-error:0.21188
# [6]	validation_0-error:0.17750	validation_1-error:0.21000
# [7]	validation_0-error:0.17313	validation_1-error:0.20875
# [8]	validation_0-error:0.16875	validation_1-error:0.20875
# [9]	validation_0-error:0.16500	validation_1-error:0.20438
# [10]	validation_0-error:0.16391	validation_1-error:0.20625
# [11]	validation_0-error:0.16078	validation_1-error:0.20625
# [12]	validation_0-error:0.15953	validation_1-error:0.20250
# [13]	validation_0-error:0.15625	validation_1-error:0.20000
# [14]	validation_0-error:0.15516	validation_1-error:0.19875
# [15]	validation_0-error:0.15359	validation_1-error:0.19812
# [16]	validation_0-error:0.14875	validation_1-error:0.19937
# [17]	validation_0-error:0.14641	validation_1-error:0.20062
# [18]	validation_0-error:0.14406	validation_1-error:0.20250
# [19]	validation_0-error:0.14156	validation_1-error:0.19875
# [20]	validation_0-error:0.13687	validation_1-error:0.20125
# [21]	validation_0-error:0.13437	validation_1-error:0.20250
# [22]	validation_0-error:0.13422	validation_1-error:0.20438
# [23]	validation_0-error:0.13031	validation_1-error:0.20500
# [24]	validation_0-error:0.12891	validation_1-error:0.20375
# [25]	validation_0-error:0.12781	validation_1-error:0.20625
# [26]	validation_0-error:0.12625	validation_1-error:0.20750
# [27]	validation_0-error:0.12562	validation_1-error:0.20688
# [28]	validation_0-error:0.12281	validation_1-error:0.20750
# [29]	validation_0-error:0.12156	validation_1-error:0.20688
# [30]	validation_0-error:0.11828	validation_1-error:0.20688
# [31]	validation_0-error:0.11484	validation_1-error:0.20688
# [32]	validation_0-error:0.11063	validation_1-error:0.20563
# [33]	validation_0-error:0.10906	validation_1-error:0.20688
# [34]	validation_0-error:0.10703	validation_1-error:0.20688
# [35]	validation_0-error:0.10672	validation_1-error:0.20563
# [36]	validation_0-error:0.10375	validation_1-error:0.20688
# [37]	validation_0-error:0.10281	validation_1-error:0.20625
# [38]	validation_0-error:0.10000	validation_1-error:0.20312
# [39]	validation_0-error:0.09922	validation_1-error:0.20062
# [40]	validation_0-error:0.09906	validation_1-error:0.20062
# [41]	validation_0-error:0.09422	validation_1-error:0.20000
# [42]	validation_0-error:0.09344	validation_1-error:0.19812
# [43]	validation_0-error:0.09391	validation_1-error:0.19937
# [44]	validation_0-error:0.09047	validation_1-error:0.19937
# [45]	validation_0-error:0.08922	validation_1-error:0.19875
# [46]	validation_0-error:0.08719	validation_1-error:0.19812
# [47]	validation_0-error:0.08469	validation_1-error:0.19812
# [48]	validation_0-error:0.08453	validation_1-error:0.19750
# [49]	validation_0-error:0.08375	validation_1-error:0.19687
# [50]	validation_0-error:0.08281	validation_1-error:0.19750
# [51]	validation_0-error:0.08188	validation_1-error:0.19875
# [52]	validation_0-error:0.08250	validation_1-error:0.19812
# [53]	validation_0-error:0.08109	validation_1-error:0.19875
# [54]	validation_0-error:0.07875	validation_1-error:0.20250
# [55]	validation_0-error:0.07672	validation_1-error:0.19937
# [56]	validation_0-error:0.07125	validation_1-error:0.20062
# [57]	validation_0-error:0.06938	validation_1-error:0.19937
# [58]	validation_0-error:0.06766	validation_1-error:0.20125
# [59]	validation_0-error:0.06703	validation_1-error:0.20062
# [60]	validation_0-error:0.06625	validation_1-error:0.19875
# [61]	validation_0-error:0.06422	validation_1-error:0.19812
# [62]	validation_0-error:0.06234	validation_1-error:0.19625
# [63]	validation_0-error:0.06172	validation_1-error:0.19625
# [64]	validation_0-error:0.06078	validation_1-error:0.19687
# [65]	validation_0-error:0.05875	validation_1-error:0.19750
# [66]	validation_0-error:0.05875	validation_1-error:0.19812
# [67]	validation_0-error:0.05828	validation_1-error:0.19687
# [68]	validation_0-error:0.05734	validation_1-error:0.19625
# [69]	validation_0-error:0.05625	validation_1-error:0.19562
# [70]	validation_0-error:0.05281	validation_1-error:0.19625
# [71]	validation_0-error:0.05203	validation_1-error:0.19625
# [72]	validation_0-error:0.04984	validation_1-error:0.19750
# [73]	validation_0-error:0.04875	validation_1-error:0.19750
# [74]	validation_0-error:0.04672	validation_1-error:0.20062
# [75]	validation_0-error:0.04484	validation_1-error:0.20000
# [76]	validation_0-error:0.04375	validation_1-error:0.19937
# [77]	validation_0-error:0.04297	validation_1-error:0.20187
# [78]	validation_0-error:0.04031	validation_1-error:0.19875
# [79]	validation_0-error:0.03844	validation_1-error:0.20125
# [80]	validation_0-error:0.03812	validation_1-error:0.20375
# [81]	validation_0-error:0.03797	validation_1-error:0.20438
# [82]	validation_0-error:0.03750	validation_1-error:0.20438
# [83]	validation_0-error:0.03578	validation_1-error:0.20312
# [84]	validation_0-error:0.03516	validation_1-error:0.20125
# [85]	validation_0-error:0.03453	validation_1-error:0.20250
# [86]	validation_0-error:0.03438	validation_1-error:0.20312
# [87]	validation_0-error:0.03297	validation_1-error:0.20312
# [88]	validation_0-error:0.03297	validation_1-error:0.20312
# [89]	validation_0-error:0.03172	validation_1-error:0.20312
# [90]	validation_0-error:0.03172	validation_1-error:0.20375
# [91]	validation_0-error:0.03078	validation_1-error:0.20125
# [92]	validation_0-error:0.03031	validation_1-error:0.20250
# [93]	validation_0-error:0.03047	validation_1-error:0.20250
# [94]	validation_0-error:0.03000	validation_1-error:0.20250
# [95]	validation_0-error:0.02984	validation_1-error:0.20312
# [96]	validation_0-error:0.02984	validation_1-error:0.20312
# [97]	validation_0-error:0.02875	validation_1-error:0.20438
# [98]	validation_0-error:0.02703	validation_1-error:0.20500
# [99]	validation_0-error:0.02594	validation_1-error:0.20625
# [100]	validation_0-error:0.02641	validation_1-error:0.20563
# [101]	validation_0-error:0.02562	validation_1-error:0.20500
# [102]	validation_0-error:0.02562	validation_1-error:0.20500
# [103]	validation_0-error:0.02531	validation_1-error:0.20563
# [104]	validation_0-error:0.02406	validation_1-error:0.20813
# [105]	validation_0-error:0.02453	validation_1-error:0.20750
# [106]	validation_0-error:0.02187	validation_1-error:0.20688
# [107]	validation_0-error:0.02172	validation_1-error:0.20500
# [108]	validation_0-error:0.02125	validation_1-error:0.20438
# [109]	validation_0-error:0.02156	validation_1-error:0.20563
# [110]	validation_0-error:0.02109	validation_1-error:0.20625
# [111]	validation_0-error:0.02078	validation_1-error:0.20125
# [112]	validation_0-error:0.02078	validation_1-error:0.20062
# [113]	validation_0-error:0.02031	validation_1-error:0.20062
# [114]	validation_0-error:0.01906	validation_1-error:0.20250
# [115]	validation_0-error:0.01828	validation_1-error:0.20312
# [116]	validation_0-error:0.01812	validation_1-error:0.20312
# [117]	validation_0-error:0.01766	validation_1-error:0.20250
# [118]	validation_0-error:0.01766	validation_1-error:0.20375
# [119]	validation_0-error:0.01766	validation_1-error:0.20187
# [120]	validation_0-error:0.01797	validation_1-error:0.20125
# [121]	validation_0-error:0.01812	validation_1-error:0.20250
# [122]	validation_0-error:0.01812	validation_1-error:0.20312
# [123]	validation_0-error:0.01703	validation_1-error:0.20187
# [124]	validation_0-error:0.01672	validation_1-error:0.20250
# [125]	validation_0-error:0.01500	validation_1-error:0.20312
# [126]	validation_0-error:0.01438	validation_1-error:0.20438
# [127]	validation_0-error:0.01453	validation_1-error:0.20375
# [128]	validation_0-error:0.01422	validation_1-error:0.20375
# [129]	validation_0-error:0.01359	validation_1-error:0.20438
# [130]	validation_0-error:0.01344	validation_1-error:0.20250
# [131]	validation_0-error:0.01328	validation_1-error:0.20187
# [132]	validation_0-error:0.01281	validation_1-error:0.20125
# [133]	validation_0-error:0.01203	validation_1-error:0.20187
# [134]	validation_0-error:0.01219	validation_1-error:0.20438
# [135]	validation_0-error:0.01141	validation_1-error:0.20000
# [136]	validation_0-error:0.01078	validation_1-error:0.20187
# [137]	validation_0-error:0.01016	validation_1-error:0.20312
# [138]	validation_0-error:0.00937	validation_1-error:0.20500
# [139]	validation_0-error:0.00891	validation_1-error:0.20438
# [140]	validation_0-error:0.00734	validation_1-error:0.20375
# [141]	validation_0-error:0.00781	validation_1-error:0.20375
# [142]	validation_0-error:0.00766	validation_1-error:0.20500
# [143]	validation_0-error:0.00766	validation_1-error:0.20500
# [144]	validation_0-error:0.00734	validation_1-error:0.20500
# [145]	validation_0-error:0.00672	validation_1-error:0.20563
# [146]	validation_0-error:0.00703	validation_1-error:0.20438
# [147]	validation_0-error:0.00688	validation_1-error:0.20500
# [148]	validation_0-error:0.00609	validation_1-error:0.20500
# [149]	validation_0-error:0.00625	validation_1-error:0.20438
# [150]	validation_0-error:0.00625	validation_1-error:0.20500
# [151]	validation_0-error:0.00578	validation_1-error:0.20688
# [152]	validation_0-error:0.00547	validation_1-error:0.20625
# [153]	validation_0-error:0.00500	validation_1-error:0.20625
# [154]	validation_0-error:0.00484	validation_1-error:0.20625
# [155]	validation_0-error:0.00484	validation_1-error:0.20625
# [156]	validation_0-error:0.00469	validation_1-error:0.20625
# [157]	validation_0-error:0.00469	validation_1-error:0.20625
# [158]	validation_0-error:0.00422	validation_1-error:0.20688
# [159]	validation_0-error:0.00359	validation_1-error:0.20625
# [160]	validation_0-error:0.00359	validation_1-error:0.20750
# [161]	validation_0-error:0.00313	validation_1-error:0.20563
# [162]	validation_0-error:0.00297	validation_1-error:0.20563
# [163]	validation_0-error:0.00297	validation_1-error:0.20625
# [164]	validation_0-error:0.00281	validation_1-error:0.20375
# [165]	validation_0-error:0.00219	validation_1-error:0.20438
# [166]	validation_0-error:0.00219	validation_1-error:0.20375
# [167]	validation_0-error:0.00187	validation_1-error:0.20688
# [168]	validation_0-error:0.00203	validation_1-error:0.20688
# [169]	validation_0-error:0.00203	validation_1-error:0.20625
# [170]	validation_0-error:0.00203	validation_1-error:0.20688
# [171]	validation_0-error:0.00203	validation_1-error:0.20750
# [172]	validation_0-error:0.00203	validation_1-error:0.20750
# [173]	validation_0-error:0.00203	validation_1-error:0.20688
# [174]	validation_0-error:0.00203	validation_1-error:0.20625
# [175]	validation_0-error:0.00203	validation_1-error:0.20500
# [176]	validation_0-error:0.00203	validation_1-error:0.20500
# [177]	validation_0-error:0.00203	validation_1-error:0.20625
# [178]	validation_0-error:0.00203	validation_1-error:0.20688
# [179]	validation_0-error:0.00203	validation_1-error:0.20500
# [180]	validation_0-error:0.00203	validation_1-error:0.20438
# [181]	validation_0-error:0.00203	validation_1-error:0.20500
# [182]	validation_0-error:0.00203	validation_1-error:0.20438
# [183]	validation_0-error:0.00203	validation_1-error:0.20563
# [184]	validation_0-error:0.00203	validation_1-error:0.20688
# [185]	validation_0-error:0.00187	validation_1-error:0.20813
# [186]	validation_0-error:0.00187	validation_1-error:0.20875
# [187]	validation_0-error:0.00172	validation_1-error:0.20875
# [188]	validation_0-error:0.00156	validation_1-error:0.20688
# [189]	validation_0-error:0.00141	validation_1-error:0.20750
# [190]	validation_0-error:0.00141	validation_1-error:0.20750
# [191]	validation_0-error:0.00141	validation_1-error:0.20750
# [192]	validation_0-error:0.00125	validation_1-error:0.20813
# [193]	validation_0-error:0.00125	validation_1-error:0.20875
# [194]	validation_0-error:0.00125	validation_1-error:0.20875
# [195]	validation_0-error:0.00125	validation_1-error:0.20563
# [196]	validation_0-error:0.00125	validation_1-error:0.20438
# [197]	validation_0-error:0.00094	validation_1-error:0.20625
# [198]	validation_0-error:0.00094	validation_1-error:0.20750
# [199]	validation_0-error:0.00094	validation_1-error:0.20625
# [200]	validation_0-error:0.00094	validation_1-error:0.20625
# [201]	validation_0-error:0.00063	validation_1-error:0.20625
# [202]	validation_0-error:0.00063	validation_1-error:0.20688
# [203]	validation_0-error:0.00063	validation_1-error:0.20563
# [204]	validation_0-error:0.00063	validation_1-error:0.20563
# [205]	validation_0-error:0.00063	validation_1-error:0.20125
# [206]	validation_0-error:0.00063	validation_1-error:0.20250
# [207]	validation_0-error:0.00063	validation_1-error:0.20375
# [208]	validation_0-error:0.00063	validation_1-error:0.20375
# [209]	validation_0-error:0.00047	validation_1-error:0.20500
# [210]	validation_0-error:0.00047	validation_1-error:0.20312
# [211]	validation_0-error:0.00031	validation_1-error:0.20563
# [212]	validation_0-error:0.00031	validation_1-error:0.20688
# [213]	validation_0-error:0.00031	validation_1-error:0.20625
# [214]	validation_0-error:0.00031	validation_1-error:0.20500
# [215]	validation_0-error:0.00031	validation_1-error:0.20563
# [216]	validation_0-error:0.00031	validation_1-error:0.20563
# [217]	validation_0-error:0.00031	validation_1-error:0.20625
# [218]	validation_0-error:0.00031	validation_1-error:0.20688
# [219]	validation_0-error:0.00047	validation_1-error:0.20625
# [220]	validation_0-error:0.00047	validation_1-error:0.20563
# [221]	validation_0-error:0.00047	validation_1-error:0.20438
# [222]	validation_0-error:0.00047	validation_1-error:0.20500
# [223]	validation_0-error:0.00047	validation_1-error:0.20250
# [224]	validation_0-error:0.00047	validation_1-error:0.20312
# [225]	validation_0-error:0.00047	validation_1-error:0.20375
# [226]	validation_0-error:0.00047	validation_1-error:0.20250
# [227]	validation_0-error:0.00031	validation_1-error:0.20375
# [228]	validation_0-error:0.00031	validation_1-error:0.20438
# [229]	validation_0-error:0.00031	validation_1-error:0.20500
# [230]	validation_0-error:0.00016	validation_1-error:0.20688
# [231]	validation_0-error:0.00016	validation_1-error:0.20625
# [232]	validation_0-error:0.00016	validation_1-error:0.20563
# [233]	validation_0-error:0.00016	validation_1-error:0.20625
# [234]	validation_0-error:0.00016	validation_1-error:0.20500
# [235]	validation_0-error:0.00016	validation_1-error:0.20563
# [236]	validation_0-error:0.00000	validation_1-error:0.20688
# [237]	validation_0-error:0.00000	validation_1-error:0.20875
# [238]	validation_0-error:0.00000	validation_1-error:0.20750
# [239]	validation_0-error:0.00000	validation_1-error:0.20750
# [240]	validation_0-error:0.00000	validation_1-error:0.20875
# [241]	validation_0-error:0.00000	validation_1-error:0.20938
# [242]	validation_0-error:0.00000	validation_1-error:0.20813
# [243]	validation_0-error:0.00000	validation_1-error:0.20688
# [244]	validation_0-error:0.00000	validation_1-error:0.20875
# [245]	validation_0-error:0.00000	validation_1-error:0.21000
# [246]	validation_0-error:0.00000	validation_1-error:0.21000
# [247]	validation_0-error:0.00000	validation_1-error:0.20875
# [248]	validation_0-error:0.00000	validation_1-error:0.21000
# [249]	validation_0-error:0.00000	validation_1-error:0.21063
# [250]	validation_0-error:0.00000	validation_1-error:0.21063
# [251]	validation_0-error:0.00000	validation_1-error:0.21063
# [252]	validation_0-error:0.00000	validation_1-error:0.20938
# [253]	validation_0-error:0.00000	validation_1-error:0.21125
# [254]	validation_0-error:0.00000	validation_1-error:0.21000
# [255]	validation_0-error:0.00000	validation_1-error:0.20938
# [256]	validation_0-error:0.00000	validation_1-error:0.21000
# [257]	validation_0-error:0.00000	validation_1-error:0.20938
# [258]	validation_0-error:0.00000	validation_1-error:0.21000
# [259]	validation_0-error:0.00000	validation_1-error:0.21063
# [260]	validation_0-error:0.00000	validation_1-error:0.20938
# [261]	validation_0-error:0.00000	validation_1-error:0.21000
# [262]	validation_0-error:0.00000	validation_1-error:0.21250
# [263]	validation_0-error:0.00000	validation_1-error:0.21125
# [264]	validation_0-error:0.00000	validation_1-error:0.21250
# [265]	validation_0-error:0.00000	validation_1-error:0.21250
# [266]	validation_0-error:0.00000	validation_1-error:0.21125
# [267]	validation_0-error:0.00000	validation_1-error:0.21125
# [268]	validation_0-error:0.00000	validation_1-error:0.21063
# [269]	validation_0-error:0.00000	validation_1-error:0.21063
# AUC score: 0.7316365829025652
# ACC score: 0.801375

# %%
# CAT模型五折交叉验证
import catboost
cat_params = {
    'eval_metric': 'Accuracy',
    'random_seed': 666,
    'logging_level': 'Verbose',
    'use_best_model': True,
    'loss_function': 'Logloss',
    'task_type':'GPU',
    'learning_rate' : 0.1
}
oof_cat = np.zeros(len(X_train))
predictions_cat = np.zeros((len(X_test)))

for fold_, (trn_idx, val_idx) in enumerate(KF.split(X_train.values, y.values)):
    print("fold n°{}".format(fold_))
    print('trn_idx:',trn_idx)
    print('val_idx:',val_idx)
    trn_data = catboost.Pool(X_train.iloc[trn_idx],label=y.iloc[trn_idx])    
    val_data = catboost.Pool(X_train.iloc[val_idx],label=y.iloc[val_idx])
    num_round = 10000
    clf = catboost.train(
                    params=cat_params,
                    pool=trn_data,
                    iterations=num_round,
                    eval_set=val_data,
                    verbose_eval=500,
                    early_stopping_rounds=200,
    )
        
    oof_cat[val_idx] = [i[1] for i in clf.predict(X_train.iloc[val_idx], prediction_type='Probability')]
    predictions_cat[:] += [i[1] / 5 for i in clf.predict(X_test, prediction_type='Probability')]
print("AUC score: {}".format(roc_auc_score(y, oof_cat)))
print("ACC score: {}".format(accuracy_score(y, [1 if i >= 0.5 else 0 for i in oof_cat])))
# Out:
# fold n°0
# trn_idx: [   2    3    4 ... 7996 7997 7998]
# val_idx: [   0    1   44 ... 7990 7995 7999]
# 0:	learn: 0.7650000	test: 0.7462500	best: 0.7462500 (0)	total: 46.7ms	remaining: 7m 46s
# bestTest = 0.794375
# bestIteration = 256
# Shrink model to first 257 iterations.
# fold n°1
# trn_idx: [   0    1    2 ... 7997 7998 7999]
# val_idx: [  15   28   35 ... 7986 7993 7996]
# 0:	learn: 0.7634375	test: 0.7537500	best: 0.7537500 (0)	total: 45.3ms	remaining: 7m 33s
# bestTest = 0.8
# bestIteration = 185
# Shrink model to first 186 iterations.
# fold n°2
# trn_idx: [   0    1    2 ... 7997 7998 7999]
# val_idx: [   3    4   14 ... 7977 7978 7994]
# 0:	learn: 0.7528125	test: 0.7731250	best: 0.7731250 (0)	total: 43.8ms	remaining: 7m 18s
# bestTest = 0.81375
# bestIteration = 294
# Shrink model to first 295 iterations.
# fold n°3
# trn_idx: [   0    1    3 ... 7995 7996 7999]
# val_idx: [   2    6    8 ... 7992 7997 7998]
# 0:	learn: 0.7598438	test: 0.7512500	best: 0.7512500 (0)	total: 44.4ms	remaining: 7m 23s
# bestTest = 0.795
# bestIteration = 289
# Shrink model to first 290 iterations.
# fold n°4
# trn_idx: [   0    1    2 ... 7997 7998 7999]
# val_idx: [   5    7   10 ... 7979 7985 7989]
# 0:	learn: 0.7632813	test: 0.7562500	best: 0.7562500 (0)	total: 46.2ms	remaining: 7m 42s
# bestTest = 0.806875
# bestIteration = 214
# Shrink model to first 215 iterations.
# AUC score: 0.8001973599466837
# ACC score: 0.802

# %%
# 三个模型概率均值融合
submit = pd.read_csv('submit_example.csv')
result = (predictions_lgb + predictions_xgb + predictions_cat) / 3
submit['y'] = [1 if i >= 0.5 else 0 for i in result]
submit.to_csv('submit_combine.csv', index=False)
