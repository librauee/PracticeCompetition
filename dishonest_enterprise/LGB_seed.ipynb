# %%
"""
作者：librauee
微信公众号：老肥码码码
日期：2020.12.15
线上得分：0.873423
截至日期排名：2
"""
import pandas as pd
from tqdm import tqdm
import warnings
import lightgbm as lgb
import numpy as np
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import roc_auc_score, f1_score

warnings.filterwarnings('ignore')

# %%
# 数据读取并做简单的特征工程
train = pd.read_csv('train.csv')
test = pd.read_csv('test_noLabel.csv')
y = train['Label']

data = pd.concat([train, test], axis=0).reset_index(drop=True)

data['assets_1'] = data['assets_1'].fillna(data['assets_1'].mean())
data['assets_2'] = data['assets_2'].fillna(data['assets_2'].mean())
data['assets_sum'] = data['assets_2'] + data['assets_1']

data['expenditure_1'] = data['expenditure_1'].fillna(data['expenditure_1'].mean())
data['expenditure_2'] = data['expenditure_2'].fillna(data['expenditure_2'].mean())
data['expenditure_3'] = data['expenditure_3'].fillna(data['expenditure_3'].mean())
data['expenditure_sum'] = data['expenditure_1'] + data['expenditure_2'] + data['expenditure_3']

data['investment'] = data['investment'].fillna(data['investment'].mean())
data['capital'] = data['capital'].fillna(data['capital'].mean())
data['income'] = data['income'].fillna(data['income'].mean())

data['stock'] = data['stock'].fillna(data['stock'].mean())
data['tax'] = data['tax'].fillna(data['tax'].mean())

data['investment-capital'] = data['investment'] - data['capital']
data['investment/capital'] = data['investment'] / data['capital']
data['income-expenditure'] = data['income'] - data['expenditure_sum']

data['stock/tax'] = data['stock'] / data['tax']

# %%
# 过采样， 扩充正样本至与负样本数量相同
from imblearn.over_sampling import RandomOverSampler


train, test = data[~data['Label'].isna()], data[data['Label'].isna()]
train.drop(['ID', 'Label'], axis=1, inplace=True)
X_test = test.drop(['ID', 'Label'], axis=1)
 
ros = RandomOverSampler(random_state=0)
X_train, y = ros.fit_sample(train, y)

features = X_train.columns

cat_cols = ['code']
X_train[cat_cols] = X_train[cat_cols].astype('category')
X_test[cat_cols] = X_test[cat_cols].astype('category')

# %%
# 不同种子lgb 概率均值
predictions_lgb = np.zeros((len(X_test)))
params = {
          'objective':'binary',
          'metric':'binary_error', 
          'verbose':-1,
          'num_iterations': 10000, 
}

seeds = [2019, 2020, 2021]
for seed in seeds:
    KF = StratifiedKFold(n_splits=5, shuffle=True, random_state=seed)
    oof_lgb = np.zeros(len(X_train))
    for fold_, (trn_idx, val_idx) in enumerate(KF.split(X_train.values, y.values)):
        print("fold n°{}".format(fold_))
        print('trn_idx:',trn_idx)
        print('val_idx:',val_idx)
        trn_data = lgb.Dataset(X_train.iloc[trn_idx][features],label=y.iloc[trn_idx])    
        val_data = lgb.Dataset(X_train.iloc[val_idx][features],label=y.iloc[val_idx])
        num_round = 10000
        clf = lgb.train(
            params,
                        trn_data,
                        num_round,
                        valid_sets = [trn_data, val_data],
                        verbose_eval=500,
                        early_stopping_rounds=200,  
            categorical_feature=cat_cols,
        )

        oof_lgb[val_idx] = clf.predict(X_train.iloc[val_idx][features], num_iteration=clf.best_iteration)
        predictions_lgb[:] += clf.predict(X_test[features], num_iteration=clf.best_iteration) / 5 / len(seeds)
    print("AUC score: {}".format(roc_auc_score(y, oof_lgb)))
    print("F1: {}".format(f1_score(y, [1 if i >= 0.5 else 0 for i in oof_lgb], average='macro')))
# Out:
# fold n°0
# trn_idx: [    1     2     3 ... 35775 35776 35777]
# val_idx: [    0     6     9 ... 35729 35753 35755]
# Training until validation scores don't improve for 200 rounds
# [500]	training's binary_error: 0.0339599	valid_1's binary_error: 0.0480715
# [1000]	training's binary_error: 0.019775	valid_1's binary_error: 0.039128
# [1500]	training's binary_error: 0.0171197	valid_1's binary_error: 0.0354947
# Early stopping, best iteration is:
# [1651]	training's binary_error: 0.0167004	valid_1's binary_error: 0.0343767
# fold n°1
# trn_idx: [    0     1     2 ... 35774 35775 35777]
# val_idx: [    7    23    25 ... 35762 35764 35776]
# Training until validation scores don't improve for 200 rounds
# [500]	training's binary_error: 0.0317588	valid_1's binary_error: 0.0487703
# [1000]	training's binary_error: 0.0204039	valid_1's binary_error: 0.0406652
# [1500]	training's binary_error: 0.0176787	valid_1's binary_error: 0.0361934
# [2000]	training's binary_error: 0.0170498	valid_1's binary_error: 0.034796
# Early stopping, best iteration is:
# [2012]	training's binary_error: 0.0170498	valid_1's binary_error: 0.0345165
# fold n°2
# trn_idx: [    0     1     2 ... 35774 35776 35777]
# val_idx: [    3     4     5 ... 35768 35772 35775]
# Training until validation scores don't improve for 200 rounds
# [500]	training's binary_error: 0.0324226	valid_1's binary_error: 0.0479318
# [1000]	training's binary_error: 0.0196003	valid_1's binary_error: 0.038569
# [1500]	training's binary_error: 0.0171896	valid_1's binary_error: 0.034796
# Early stopping, best iteration is:
# [1623]	training's binary_error: 0.0168053	valid_1's binary_error: 0.0338178
# fold n°3
# trn_idx: [    0     1     2 ... 35775 35776 35777]
# val_idx: [   10    20    26 ... 35769 35770 35771]
# Training until validation scores don't improve for 200 rounds
# [500]	training's binary_error: 0.0317926	valid_1's binary_error: 0.0454228
# [1000]	training's binary_error: 0.0201936	valid_1's binary_error: 0.0374563
# [1500]	training's binary_error: 0.0176082	valid_1's binary_error: 0.0346611
# Early stopping, best iteration is:
# [1751]	training's binary_error: 0.0170842	valid_1's binary_error: 0.0325646
# fold n°4
# trn_idx: [    0     3     4 ... 35772 35775 35776]
# val_idx: [    1     2     8 ... 35773 35774 35777]
# Training until validation scores don't improve for 200 rounds
# [500]	training's binary_error: 0.0324564	valid_1's binary_error: 0.0497554
# [1000]	training's binary_error: 0.0206477	valid_1's binary_error: 0.0405311
# [1500]	training's binary_error: 0.0177829	valid_1's binary_error: 0.0381551
# [2000]	training's binary_error: 0.0170492	valid_1's binary_error: 0.0359189
# Early stopping, best iteration is:
# [1979]	training's binary_error: 0.0170492	valid_1's binary_error: 0.0357792
# AUC score: 0.9857970712687494
# F1: 0.9657489452638102
# fold n°0
# trn_idx: [    0     1     2 ... 35774 35776 35777]
# val_idx: [    4     9    22 ... 35765 35769 35775]
# Training until validation scores don't improve for 200 rounds
# [500]	training's binary_error: 0.0336454	valid_1's binary_error: 0.0438793
# [1000]	training's binary_error: 0.0207183	valid_1's binary_error: 0.034796
# [1500]	training's binary_error: 0.0179233	valid_1's binary_error: 0.0310229
# [2000]	training's binary_error: 0.0173293	valid_1's binary_error: 0.0306037
# [2500]	training's binary_error: 0.0171546	valid_1's binary_error: 0.0290665
# Early stopping, best iteration is:
# [2601]	training's binary_error: 0.0171546	valid_1's binary_error: 0.0289268
# fold n°1
# trn_idx: [    1     2     4 ... 35775 35776 35777]
# val_idx: [    0     3    10 ... 35752 35763 35772]
# Training until validation scores don't improve for 200 rounds
# [500]	training's binary_error: 0.0309203	valid_1's binary_error: 0.0521241
# [1000]	training's binary_error: 0.0195654	valid_1's binary_error: 0.0422023
# [1500]	training's binary_error: 0.0165257	valid_1's binary_error: 0.0378703
# [2000]	training's binary_error: 0.0158969	valid_1's binary_error: 0.0366126
# Early stopping, best iteration is:
# [1891]	training's binary_error: 0.0159318	valid_1's binary_error: 0.0363331
# fold n°2
# trn_idx: [    0     3     4 ... 35775 35776 35777]
# val_idx: [    1     2     8 ... 35755 35758 35770]
# Training until validation scores don't improve for 200 rounds
# [500]	training's binary_error: 0.031619	valid_1's binary_error: 0.0448575
# [1000]	training's binary_error: 0.0198449	valid_1's binary_error: 0.0378703
# [1500]	training's binary_error: 0.0172595	valid_1's binary_error: 0.033678
# [2000]	training's binary_error: 0.0167004	valid_1's binary_error: 0.0322806
# Early stopping, best iteration is:
# [2071]	training's binary_error: 0.0167004	valid_1's binary_error: 0.0320011
# fold n°3
# trn_idx: [    0     1     2 ... 35775 35776 35777]
# val_idx: [    7    15    20 ... 35761 35762 35774]
# Training until validation scores don't improve for 200 rounds
# [500]	training's binary_error: 0.032666	valid_1's binary_error: 0.0508735
# [1000]	training's binary_error: 0.0205429	valid_1's binary_error: 0.0408106
# [1500]	training's binary_error: 0.0179226	valid_1's binary_error: 0.0356394
# Early stopping, best iteration is:
# [1713]	training's binary_error: 0.0175733	valid_1's binary_error: 0.0343816
# fold n°4
# trn_idx: [    0     1     2 ... 35772 35774 35775]
# val_idx: [    5     6    11 ... 35773 35776 35777]
# Training until validation scores don't improve for 200 rounds
# [500]	training's binary_error: 0.032701	valid_1's binary_error: 0.0483578
# [1000]	training's binary_error: 0.0194249	valid_1's binary_error: 0.0385744
# [1500]	training's binary_error: 0.017189	valid_1's binary_error: 0.0342418
# Early stopping, best iteration is:
# [1355]	training's binary_error: 0.0175383	valid_1's binary_error: 0.0336827
# AUC score: 0.985810167475802
# F1: 0.9668987986028046
# fold n°0
# trn_idx: [    0     1     4 ... 35774 35775 35777]
# val_idx: [    2     3    14 ... 35765 35773 35776]
# Training until validation scores don't improve for 200 rounds
# [500]	training's binary_error: 0.0318985	valid_1's binary_error: 0.044578
# [1000]	training's binary_error: 0.0200545	valid_1's binary_error: 0.0368921
# Early stopping, best iteration is:
# [1197]	training's binary_error: 0.0184823	valid_1's binary_error: 0.0346562
# fold n°1
# trn_idx: [    1     2     3 ... 35774 35776 35777]
# val_idx: [    0     5     7 ... 35768 35772 35775]
# Training until validation scores don't improve for 200 rounds
# [500]	training's binary_error: 0.032772	valid_1's binary_error: 0.0470933
# [1000]	training's binary_error: 0.0208581	valid_1's binary_error: 0.0377306
# [1500]	training's binary_error: 0.0183076	valid_1's binary_error: 0.0332588
# Early stopping, best iteration is:
# [1523]	training's binary_error: 0.0182727	valid_1's binary_error: 0.0328396
# fold n°2
# trn_idx: [    0     1     2 ... 35775 35776 35777]
# val_idx: [    4     6    10 ... 35770 35771 35774]
# Training until validation scores don't improve for 200 rounds
# [500]	training's binary_error: 0.0315841	valid_1's binary_error: 0.0517049
# [1000]	training's binary_error: 0.0191461	valid_1's binary_error: 0.0408049
# [1500]	training's binary_error: 0.0168053	valid_1's binary_error: 0.0375908
# Early stopping, best iteration is:
# [1638]	training's binary_error: 0.0165257	valid_1's binary_error: 0.0363331
# fold n°3
# trn_idx: [    0     1     2 ... 35775 35776 35777]
# val_idx: [    8     9    12 ... 35754 35764 35767]
# Training until validation scores don't improve for 200 rounds
# [500]	training's binary_error: 0.0325263	valid_1's binary_error: 0.0498952
# [1000]	training's binary_error: 0.019949	valid_1's binary_error: 0.0398323
# [1500]	training's binary_error: 0.0170143	valid_1's binary_error: 0.0381551
# [2000]	training's binary_error: 0.0165601	valid_1's binary_error: 0.036478
# [2500]	training's binary_error: 0.0165601	valid_1's binary_error: 0.0350804
# Early stopping, best iteration is:
# [2353]	training's binary_error: 0.0165601	valid_1's binary_error: 0.0348008
# fold n°4
# trn_idx: [    0     2     3 ... 35774 35775 35776]
# val_idx: [    1    16    26 ... 35766 35769 35777]
# Training until validation scores don't improve for 200 rounds
# [500]	training's binary_error: 0.0318276	valid_1's binary_error: 0.0494759
# [1000]	training's binary_error: 0.0194948	valid_1's binary_error: 0.0402516
# [1500]	training's binary_error: 0.0172239	valid_1's binary_error: 0.0357792
# Early stopping, best iteration is:
# [1424]	training's binary_error: 0.0173637	valid_1's binary_error: 0.0349406
# AUC score: 0.9852610407954787
# F1: 0.9652440466603518

# %%
# 提交
submit = pd.read_csv('submit_example.csv')
submit['Label'] = [1 if i >= 0.5 else 0 for i in predictions_lgb]
submit.to_csv('submit_seed.csv', index=False)
