# %%
"""
作者：librauee
微信公众号：老肥码码码
日期：2020.12.18
线上得分：3.156927
截至日期排名：2
"""
from sklearn.metrics import accuracy_score
import pandas as pd
from tqdm import tqdm
import warnings
import lightgbm as lgb
import numpy as np
from sklearn.model_selection import StratifiedKFold, KFold
from sklearn.metrics import mean_squared_error
from pypinyin import lazy_pinyin

warnings.filterwarnings('ignore')

# %%
# 数据读取、合并
train = pd.read_csv('train.csv')
test = pd.read_csv('test_noLabel.csv')
y = train['Label']
data = pd.concat([train, test], axis=0)

# %%
# 特征工程 方位特征、房屋数量、面积等特征构造
def location(x):
    loc = x.split()[0]
    loc_dic = {'东': 1, '南': 2, '西': 3, '北': 4, '东南': 5, '西南': 6, '东北': 7, '西北': 8 }
    return loc_dic[loc]

data['房屋朝向'] = data['房屋朝向'].apply(location)
data['小区地铁数量'] = data.groupby('小区名')['地铁站点'].transform('nunique')
data['小区地铁线路数量'] = data.groupby('小区名')['地铁线路'].transform('nunique')
data['总房间数'] = data['卧室数量'] + data['厅的数量'] + data['卫的数量']
data['房间平均面积'] = data['房屋面积'] / data['总房间数']
data['卧室面积'] = data['房屋面积'] * (data['卧室数量'] / data['总房间数'])
data['厅的面积'] = data['房屋面积'] * (data['厅的数量'] / data['总房间数'])
data['卫的面积'] = data['房屋面积'] * (data['卫的数量'] / data['总房间数'])
data['除卧室外面积'] = data['房屋面积'] - data['卧室面积']
data['相对高度'] = data['楼层'] / (data['总楼层'] + 1)

# %%
# 将类别特征转换为category类型
# 去除无关列
# 中文列名拼音转换
X_train, X_test = data[~data['Label'].isna()], data[data['Label'].isna()]
X_train = X_train.drop(['ID', 'Label'], axis=1)
X_test = X_test.drop(['ID'], axis=1)
X_train.columns = [''.join(lazy_pinyin(i)) for i in X_train.columns]
X_test.columns = [''.join(lazy_pinyin(i)) for i in X_test.columns]
features = X_train.columns

cat_cols = ['位置', '出租方式', '区', '地铁站点', '地铁线路', '小区名', '居住状态', '房屋朝向', '装修情况']

cat_cols = [''.join(lazy_pinyin(i)) for i in cat_cols]
X_train[cat_cols] = X_train[cat_cols].astype('category')
X_test[cat_cols] = X_test[cat_cols].astype('category')

# %%
# LGB模型五折、不同种子求平均
predictions_lgb = np.zeros((len(X_test)))
params = {
          'metric':'mean_squared_error', 
          'num_iterations': 30000, 
}
seeds = [2019, 2020, 2021]
for seed in seeds:
    oof_lgb = np.zeros(len(X_train))
    KF = KFold(n_splits=5, shuffle=True, random_state=seed)
    for fold_, (trn_idx, val_idx) in enumerate(KF.split(X_train.values, y.values)):
        print("fold n°{}".format(fold_))
        trn_data = lgb.Dataset(X_train.iloc[trn_idx][features],label=y.iloc[trn_idx])    
        val_data = lgb.Dataset(X_train.iloc[val_idx][features],label=y.iloc[val_idx])
        clf = lgb.train(
            params,
                        trn_data,
                        valid_sets = [trn_data, val_data],
                        verbose_eval=500,
                        early_stopping_rounds=200,  
            categorical_feature=cat_cols,
        )

        oof_lgb[val_idx] = clf.predict(X_train.iloc[val_idx][features], num_iteration=clf.best_iteration)
        predictions_lgb[:] += clf.predict(X_test[features], num_iteration=clf.best_iteration) / 5 / len(seeds)
    print("MSE: {}".format(mean_squared_error(y, oof_lgb)))
# Out:
# fold n°0
# Training until validation scores don't improve for 200 rounds
# [500]	training's l2: 2.06844	valid_1's l2: 3.46719
# [1000]	training's l2: 1.53799	valid_1's l2: 2.97422
# [1500]	training's l2: 1.2055	valid_1's l2: 2.65272
# [2000]	training's l2: 1.01638	valid_1's l2: 2.4873
# [2500]	training's l2: 0.891195	valid_1's l2: 2.36498
# [3000]	training's l2: 0.79192	valid_1's l2: 2.27656
# [3500]	training's l2: 0.713878	valid_1's l2: 2.2024
# [4000]	training's l2: 0.650374	valid_1's l2: 2.14163
# [4500]	training's l2: 0.597055	valid_1's l2: 2.09618
# [5000]	training's l2: 0.548916	valid_1's l2: 2.04985
# [5500]	training's l2: 0.512664	valid_1's l2: 2.01904
# [6000]	training's l2: 0.479886	valid_1's l2: 1.99834
# [6500]	training's l2: 0.452136	valid_1's l2: 1.97841
# [7000]	training's l2: 0.426955	valid_1's l2: 1.95711
# [7500]	training's l2: 0.406609	valid_1's l2: 1.94059
# [8000]	training's l2: 0.388589	valid_1's l2: 1.92467
# [8500]	training's l2: 0.372715	valid_1's l2: 1.91367
# [9000]	training's l2: 0.359268	valid_1's l2: 1.90432
# [9500]	training's l2: 0.346215	valid_1's l2: 1.89459
# [10000]	training's l2: 0.334646	valid_1's l2: 1.88412
# [10500]	training's l2: 0.322817	valid_1's l2: 1.87697
# [11000]	training's l2: 0.312307	valid_1's l2: 1.86868
# [11500]	training's l2: 0.30301	valid_1's l2: 1.86099
# [12000]	training's l2: 0.291997	valid_1's l2: 1.85604
# [12500]	training's l2: 0.283464	valid_1's l2: 1.85054
# [13000]	training's l2: 0.275964	valid_1's l2: 1.84379
# [13500]	training's l2: 0.268381	valid_1's l2: 1.84113
# [14000]	training's l2: 0.261377	valid_1's l2: 1.83803
# [14500]	training's l2: 0.25488	valid_1's l2: 1.83419
# [15000]	training's l2: 0.248588	valid_1's l2: 1.83003
# Early stopping, best iteration is:
# [14983]	training's l2: 0.248727	valid_1's l2: 1.82997
# fold n°1
# Training until validation scores don't improve for 200 rounds
# [500]	training's l2: 2.14603	valid_1's l2: 3.14497
# [1000]	training's l2: 1.58657	valid_1's l2: 2.63062
# [1500]	training's l2: 1.2836	valid_1's l2: 2.34995
# [2000]	training's l2: 1.0801	valid_1's l2: 2.14958
# [2500]	training's l2: 0.93232	valid_1's l2: 2.00375
# [3000]	training's l2: 0.813002	valid_1's l2: 1.88119
# [3500]	training's l2: 0.734311	valid_1's l2: 1.81371
# [4000]	training's l2: 0.663273	valid_1's l2: 1.7472
# [4500]	training's l2: 0.607734	valid_1's l2: 1.69375
# [5000]	training's l2: 0.558951	valid_1's l2: 1.65109
# [5500]	training's l2: 0.521642	valid_1's l2: 1.61876
# [6000]	training's l2: 0.490272	valid_1's l2: 1.59271
# [6500]	training's l2: 0.460253	valid_1's l2: 1.56985
# [7000]	training's l2: 0.432194	valid_1's l2: 1.55114
# [7500]	training's l2: 0.409707	valid_1's l2: 1.53477
# [8000]	training's l2: 0.390708	valid_1's l2: 1.52128
# [8500]	training's l2: 0.373398	valid_1's l2: 1.50751
# [9000]	training's l2: 0.358578	valid_1's l2: 1.49721
# [9500]	training's l2: 0.344008	valid_1's l2: 1.48394
# [10000]	training's l2: 0.33089	valid_1's l2: 1.47423
# [10500]	training's l2: 0.318724	valid_1's l2: 1.46587
# [11000]	training's l2: 0.307368	valid_1's l2: 1.45724
# [11500]	training's l2: 0.297513	valid_1's l2: 1.45127
# [12000]	training's l2: 0.288492	valid_1's l2: 1.44494
# [12500]	training's l2: 0.28017	valid_1's l2: 1.44026
# [13000]	training's l2: 0.273069	valid_1's l2: 1.43687
# [13500]	training's l2: 0.265506	valid_1's l2: 1.43157
# [14000]	training's l2: 0.259168	valid_1's l2: 1.42888
# [14500]	training's l2: 0.252203	valid_1's l2: 1.42478
# [15000]	training's l2: 0.245489	valid_1's l2: 1.42127
# Early stopping, best iteration is:
# [15247]	training's l2: 0.242848	valid_1's l2: 1.4193
# fold n°2
# Training until validation scores don't improve for 200 rounds
# [500]	training's l2: 2.1439	valid_1's l2: 3.06354
# [1000]	training's l2: 1.57238	valid_1's l2: 2.60483
# [1500]	training's l2: 1.24265	valid_1's l2: 2.32453
# [2000]	training's l2: 1.02992	valid_1's l2: 2.15148
# [2500]	training's l2: 0.885585	valid_1's l2: 2.0405
# [3000]	training's l2: 0.784419	valid_1's l2: 1.95595
# [3500]	training's l2: 0.710876	valid_1's l2: 1.89855
# [4000]	training's l2: 0.647788	valid_1's l2: 1.85089
# [4500]	training's l2: 0.599551	valid_1's l2: 1.82313
# [5000]	training's l2: 0.557151	valid_1's l2: 1.79153
# [5500]	training's l2: 0.518626	valid_1's l2: 1.76851
# [6000]	training's l2: 0.486315	valid_1's l2: 1.74354
# [6500]	training's l2: 0.457898	valid_1's l2: 1.72281
# [7000]	training's l2: 0.435382	valid_1's l2: 1.70507
# [7500]	training's l2: 0.414337	valid_1's l2: 1.69166
# [8000]	training's l2: 0.395613	valid_1's l2: 1.67986
# [8500]	training's l2: 0.379114	valid_1's l2: 1.6708
# [9000]	training's l2: 0.362056	valid_1's l2: 1.66314
# [9500]	training's l2: 0.348942	valid_1's l2: 1.65457
# [10000]	training's l2: 0.336904	valid_1's l2: 1.64794
# [10500]	training's l2: 0.325353	valid_1's l2: 1.64318
# [11000]	training's l2: 0.314849	valid_1's l2: 1.63616
# [11500]	training's l2: 0.30539	valid_1's l2: 1.63001
# [12000]	training's l2: 0.296091	valid_1's l2: 1.62328
# [12500]	training's l2: 0.287119	valid_1's l2: 1.61882
# [13000]	training's l2: 0.279241	valid_1's l2: 1.61386
# [13500]	training's l2: 0.272246	valid_1's l2: 1.61037
# [14000]	training's l2: 0.266151	valid_1's l2: 1.60851
# [14500]	training's l2: 0.25998	valid_1's l2: 1.60471
# [15000]	training's l2: 0.253556	valid_1's l2: 1.60251
# [15500]	training's l2: 0.248168	valid_1's l2: 1.59975
# [16000]	training's l2: 0.242614	valid_1's l2: 1.59734
# Early stopping, best iteration is:
# [16293]	training's l2: 0.239985	valid_1's l2: 1.59598
# fold n°3
# Training until validation scores don't improve for 200 rounds
# [500]	training's l2: 2.12162	valid_1's l2: 3.12442
# [1000]	training's l2: 1.55663	valid_1's l2: 2.62465
# [1500]	training's l2: 1.23257	valid_1's l2: 2.32709
# [2000]	training's l2: 1.02965	valid_1's l2: 2.14308
# [2500]	training's l2: 0.900904	valid_1's l2: 2.02902
# [3000]	training's l2: 0.797764	valid_1's l2: 1.93975
# [3500]	training's l2: 0.713592	valid_1's l2: 1.86582
# [4000]	training's l2: 0.652833	valid_1's l2: 1.81267
# [4500]	training's l2: 0.602802	valid_1's l2: 1.76487
# [5000]	training's l2: 0.553896	valid_1's l2: 1.71952
# [5500]	training's l2: 0.519933	valid_1's l2: 1.69514
# [6000]	training's l2: 0.487119	valid_1's l2: 1.67242
# [6500]	training's l2: 0.457995	valid_1's l2: 1.64844
# [7000]	training's l2: 0.432267	valid_1's l2: 1.6313
# [7500]	training's l2: 0.410576	valid_1's l2: 1.61551
# [8000]	training's l2: 0.392347	valid_1's l2: 1.6012
# [8500]	training's l2: 0.373741	valid_1's l2: 1.58757
# [9000]	training's l2: 0.357817	valid_1's l2: 1.57769
# [9500]	training's l2: 0.344103	valid_1's l2: 1.56841
# [10000]	training's l2: 0.332618	valid_1's l2: 1.56107
# [10500]	training's l2: 0.320637	valid_1's l2: 1.5522
# [11000]	training's l2: 0.310619	valid_1's l2: 1.54605
# [11500]	training's l2: 0.299553	valid_1's l2: 1.54029
# [12000]	training's l2: 0.290395	valid_1's l2: 1.53577
# [12500]	training's l2: 0.282728	valid_1's l2: 1.53001
# [13000]	training's l2: 0.2753	valid_1's l2: 1.52591
# [13500]	training's l2: 0.26863	valid_1's l2: 1.52024
# [14000]	training's l2: 0.261374	valid_1's l2: 1.51632
# [14500]	training's l2: 0.255144	valid_1's l2: 1.51251
# [15000]	training's l2: 0.249418	valid_1's l2: 1.51052
# [15500]	training's l2: 0.244335	valid_1's l2: 1.50846
# [16000]	training's l2: 0.239086	valid_1's l2: 1.50536
# [16500]	training's l2: 0.234439	valid_1's l2: 1.50269
# [17000]	training's l2: 0.229876	valid_1's l2: 1.49953
# Early stopping, best iteration is:
# [17091]	training's l2: 0.229344	valid_1's l2: 1.49924
# fold n°4
# Training until validation scores don't improve for 200 rounds
# [500]	training's l2: 2.0889	valid_1's l2: 3.23533
# [1000]	training's l2: 1.55186	valid_1's l2: 2.80751
# [1500]	training's l2: 1.248	valid_1's l2: 2.54601
# [2000]	training's l2: 1.06966	valid_1's l2: 2.38217
# [2500]	training's l2: 0.934266	valid_1's l2: 2.26953
# [3000]	training's l2: 0.820272	valid_1's l2: 2.18096
# [3500]	training's l2: 0.732231	valid_1's l2: 2.10428
# [4000]	training's l2: 0.658508	valid_1's l2: 2.03899
# [4500]	training's l2: 0.600659	valid_1's l2: 1.99686
# [5000]	training's l2: 0.55693	valid_1's l2: 1.95893
# [5500]	training's l2: 0.516183	valid_1's l2: 1.92569
# [6000]	training's l2: 0.484195	valid_1's l2: 1.90324
# [6500]	training's l2: 0.45739	valid_1's l2: 1.87816
# [7000]	training's l2: 0.432734	valid_1's l2: 1.86655
# [7500]	training's l2: 0.41221	valid_1's l2: 1.85406
# [8000]	training's l2: 0.392952	valid_1's l2: 1.84268
# [8500]	training's l2: 0.375661	valid_1's l2: 1.82833
# [9000]	training's l2: 0.359958	valid_1's l2: 1.81932
# [9500]	training's l2: 0.345659	valid_1's l2: 1.80787
# [10000]	training's l2: 0.332621	valid_1's l2: 1.7996
# [10500]	training's l2: 0.321835	valid_1's l2: 1.79264
# [11000]	training's l2: 0.311232	valid_1's l2: 1.78786
# [11500]	training's l2: 0.300863	valid_1's l2: 1.78084
# Early stopping, best iteration is:
# [11693]	training's l2: 0.29719	valid_1's l2: 1.77906
# MSE: 1.6247076801577378
# fold n°0
# Training until validation scores don't improve for 200 rounds
# [500]	training's l2: 2.17127	valid_1's l2: 3.19183
# [1000]	training's l2: 1.59589	valid_1's l2: 2.65129
# [1500]	training's l2: 1.27743	valid_1's l2: 2.36623
# [2000]	training's l2: 1.05722	valid_1's l2: 2.14431
# [2500]	training's l2: 0.924952	valid_1's l2: 2.02774
# [3000]	training's l2: 0.817353	valid_1's l2: 1.92352
# [3500]	training's l2: 0.734011	valid_1's l2: 1.84767
# [4000]	training's l2: 0.672519	valid_1's l2: 1.79835
# [4500]	training's l2: 0.617102	valid_1's l2: 1.7501
# [5000]	training's l2: 0.568947	valid_1's l2: 1.70797
# [5500]	training's l2: 0.529193	valid_1's l2: 1.67513
# [6000]	training's l2: 0.49494	valid_1's l2: 1.64837
# [6500]	training's l2: 0.468743	valid_1's l2: 1.62671
# [7000]	training's l2: 0.444201	valid_1's l2: 1.6067
# [7500]	training's l2: 0.423896	valid_1's l2: 1.58913
# [8000]	training's l2: 0.401091	valid_1's l2: 1.57251
# [8500]	training's l2: 0.383656	valid_1's l2: 1.55985
# [9000]	training's l2: 0.367744	valid_1's l2: 1.54819
# [9500]	training's l2: 0.353674	valid_1's l2: 1.53924
# [10000]	training's l2: 0.341876	valid_1's l2: 1.53231
# [10500]	training's l2: 0.329815	valid_1's l2: 1.52622
# [11000]	training's l2: 0.319125	valid_1's l2: 1.51835
# [11500]	training's l2: 0.309342	valid_1's l2: 1.51319
# [12000]	training's l2: 0.299978	valid_1's l2: 1.50768
# [12500]	training's l2: 0.290971	valid_1's l2: 1.50209
# [13000]	training's l2: 0.282875	valid_1's l2: 1.49738
# [13500]	training's l2: 0.275663	valid_1's l2: 1.49357
# [14000]	training's l2: 0.268899	valid_1's l2: 1.48934
# [14500]	training's l2: 0.26249	valid_1's l2: 1.48517
# [15000]	training's l2: 0.256747	valid_1's l2: 1.48312
# [15500]	training's l2: 0.251265	valid_1's l2: 1.48143
# [16000]	training's l2: 0.245921	valid_1's l2: 1.47931
# [16500]	training's l2: 0.24078	valid_1's l2: 1.47651
# [17000]	training's l2: 0.235949	valid_1's l2: 1.4744
# [17500]	training's l2: 0.231537	valid_1's l2: 1.47253
# [18000]	training's l2: 0.227411	valid_1's l2: 1.47083
# [18500]	training's l2: 0.22333	valid_1's l2: 1.4681
# [19000]	training's l2: 0.219644	valid_1's l2: 1.46655
# [19500]	training's l2: 0.216224	valid_1's l2: 1.46554
# [20000]	training's l2: 0.211976	valid_1's l2: 1.46466
# Early stopping, best iteration is:
# [19805]	training's l2: 0.213627	valid_1's l2: 1.4642
# fold n°1
# Training until validation scores don't improve for 200 rounds
# [500]	training's l2: 2.19721	valid_1's l2: 2.97653
# [1000]	training's l2: 1.5934	valid_1's l2: 2.47631
# [1500]	training's l2: 1.27726	valid_1's l2: 2.22119
# [2000]	training's l2: 1.06615	valid_1's l2: 2.0494
# [2500]	training's l2: 0.915656	valid_1's l2: 1.91714
# [3000]	training's l2: 0.807268	valid_1's l2: 1.82454
# [3500]	training's l2: 0.727394	valid_1's l2: 1.76668
# [4000]	training's l2: 0.657003	valid_1's l2: 1.70095
# [4500]	training's l2: 0.606953	valid_1's l2: 1.66061
# [5000]	training's l2: 0.56076	valid_1's l2: 1.62263
# [5500]	training's l2: 0.520711	valid_1's l2: 1.59121
# [6000]	training's l2: 0.487478	valid_1's l2: 1.56861
# [6500]	training's l2: 0.460255	valid_1's l2: 1.54874
# [7000]	training's l2: 0.43686	valid_1's l2: 1.53285
# [7500]	training's l2: 0.415192	valid_1's l2: 1.51859
# [8000]	training's l2: 0.396085	valid_1's l2: 1.50763
# [8500]	training's l2: 0.379656	valid_1's l2: 1.49682
# [9000]	training's l2: 0.363403	valid_1's l2: 1.48416
# [9500]	training's l2: 0.349564	valid_1's l2: 1.4751
# [10000]	training's l2: 0.336747	valid_1's l2: 1.4654
# [10500]	training's l2: 0.325868	valid_1's l2: 1.4618
# [11000]	training's l2: 0.315917	valid_1's l2: 1.45664
# [11500]	training's l2: 0.305701	valid_1's l2: 1.44977
# [12000]	training's l2: 0.297088	valid_1's l2: 1.44323
# [12500]	training's l2: 0.288538	valid_1's l2: 1.43948
# [13000]	training's l2: 0.28092	valid_1's l2: 1.43465
# [13500]	training's l2: 0.27411	valid_1's l2: 1.43049
# [14000]	training's l2: 0.267922	valid_1's l2: 1.42689
# [14500]	training's l2: 0.261455	valid_1's l2: 1.42314
# [15000]	training's l2: 0.254863	valid_1's l2: 1.41987
# [15500]	training's l2: 0.249167	valid_1's l2: 1.41623
# [16000]	training's l2: 0.243925	valid_1's l2: 1.41369
# [16500]	training's l2: 0.239162	valid_1's l2: 1.41031
# [17000]	training's l2: 0.234281	valid_1's l2: 1.40799
# Early stopping, best iteration is:
# [17066]	training's l2: 0.233699	valid_1's l2: 1.40778
# fold n°2
# Training until validation scores don't improve for 200 rounds
# [500]	training's l2: 2.08069	valid_1's l2: 3.27399
# [1000]	training's l2: 1.5432	valid_1's l2: 2.82335
# [1500]	training's l2: 1.23044	valid_1's l2: 2.55316
# [2000]	training's l2: 1.03369	valid_1's l2: 2.39164
# [2500]	training's l2: 0.889133	valid_1's l2: 2.27459
# [3000]	training's l2: 0.782997	valid_1's l2: 2.17582
# [3500]	training's l2: 0.703756	valid_1's l2: 2.11196
# [4000]	training's l2: 0.643278	valid_1's l2: 2.06005
# [4500]	training's l2: 0.592178	valid_1's l2: 2.01685
# [5000]	training's l2: 0.550965	valid_1's l2: 1.98257
# [5500]	training's l2: 0.515781	valid_1's l2: 1.95633
# [6000]	training's l2: 0.483912	valid_1's l2: 1.93236
# [6500]	training's l2: 0.459299	valid_1's l2: 1.91613
# [7000]	training's l2: 0.43354	valid_1's l2: 1.8979
# [7500]	training's l2: 0.410848	valid_1's l2: 1.88584
# [8000]	training's l2: 0.392979	valid_1's l2: 1.87537
# [8500]	training's l2: 0.376328	valid_1's l2: 1.86394
# [9000]	training's l2: 0.359407	valid_1's l2: 1.85328
# [9500]	training's l2: 0.345771	valid_1's l2: 1.84291
# [10000]	training's l2: 0.331733	valid_1's l2: 1.83635
# [10500]	training's l2: 0.319263	valid_1's l2: 1.83161
# [11000]	training's l2: 0.308657	valid_1's l2: 1.82504
# [11500]	training's l2: 0.299214	valid_1's l2: 1.82135
# [12000]	training's l2: 0.290931	valid_1's l2: 1.81761
# [12500]	training's l2: 0.282502	valid_1's l2: 1.81253
# [13000]	training's l2: 0.275275	valid_1's l2: 1.80869
# [13500]	training's l2: 0.268923	valid_1's l2: 1.80541
# [14000]	training's l2: 0.263003	valid_1's l2: 1.80219
# [14500]	training's l2: 0.256763	valid_1's l2: 1.79964
# [15000]	training's l2: 0.250792	valid_1's l2: 1.79575
# [15500]	training's l2: 0.245448	valid_1's l2: 1.7926
# [16000]	training's l2: 0.240092	valid_1's l2: 1.78875
# [16500]	training's l2: 0.235197	valid_1's l2: 1.78642
# [17000]	training's l2: 0.230357	valid_1's l2: 1.78455
# [17500]	training's l2: 0.22571	valid_1's l2: 1.78307
# [18000]	training's l2: 0.222256	valid_1's l2: 1.781
# [18500]	training's l2: 0.218508	valid_1's l2: 1.77916
# [19000]	training's l2: 0.215214	valid_1's l2: 1.77854
# Early stopping, best iteration is:
# [19025]	training's l2: 0.215051	valid_1's l2: 1.77844
# fold n°3
# Training until validation scores don't improve for 200 rounds
# [500]	training's l2: 2.11952	valid_1's l2: 3.16291
# [1000]	training's l2: 1.56539	valid_1's l2: 2.70057
# [1500]	training's l2: 1.24551	valid_1's l2: 2.42721
# [2000]	training's l2: 1.052	valid_1's l2: 2.25647
# [2500]	training's l2: 0.897145	valid_1's l2: 2.12047
# [3000]	training's l2: 0.798877	valid_1's l2: 2.0323
# [3500]	training's l2: 0.71658	valid_1's l2: 1.95704
# [4000]	training's l2: 0.649306	valid_1's l2: 1.89772
# [4500]	training's l2: 0.592209	valid_1's l2: 1.85058
# [5000]	training's l2: 0.548282	valid_1's l2: 1.81329
# [5500]	training's l2: 0.509488	valid_1's l2: 1.7829
# [6000]	training's l2: 0.480137	valid_1's l2: 1.75984
# [6500]	training's l2: 0.453181	valid_1's l2: 1.73908
# [7000]	training's l2: 0.4297	valid_1's l2: 1.72118
# [7500]	training's l2: 0.407757	valid_1's l2: 1.70326
# [8000]	training's l2: 0.388609	valid_1's l2: 1.68739
# [8500]	training's l2: 0.370472	valid_1's l2: 1.67357
# [9000]	training's l2: 0.355944	valid_1's l2: 1.66161
# [9500]	training's l2: 0.343188	valid_1's l2: 1.6552
# [10000]	training's l2: 0.329325	valid_1's l2: 1.64737
# [10500]	training's l2: 0.316242	valid_1's l2: 1.6399
# [11000]	training's l2: 0.304941	valid_1's l2: 1.63203
# [11500]	training's l2: 0.294139	valid_1's l2: 1.6243
# [12000]	training's l2: 0.285326	valid_1's l2: 1.6183
# [12500]	training's l2: 0.277284	valid_1's l2: 1.6136
# [13000]	training's l2: 0.270232	valid_1's l2: 1.60869
# [13500]	training's l2: 0.263329	valid_1's l2: 1.60399
# [14000]	training's l2: 0.25662	valid_1's l2: 1.60064
# [14500]	training's l2: 0.250431	valid_1's l2: 1.59714
# [15000]	training's l2: 0.244084	valid_1's l2: 1.59351
# [15500]	training's l2: 0.238309	valid_1's l2: 1.59024
# [16000]	training's l2: 0.233168	valid_1's l2: 1.58821
# [16500]	training's l2: 0.228421	valid_1's l2: 1.58559
# [17000]	training's l2: 0.2238	valid_1's l2: 1.58337
# [17500]	training's l2: 0.220124	valid_1's l2: 1.5812
# [18000]	training's l2: 0.21631	valid_1's l2: 1.57955
# [18500]	training's l2: 0.212703	valid_1's l2: 1.57794
# [19000]	training's l2: 0.208945	valid_1's l2: 1.57527
# [19500]	training's l2: 0.205467	valid_1's l2: 1.57309
# Early stopping, best iteration is:
# [19721]	training's l2: 0.204081	valid_1's l2: 1.5722
# fold n°4
# Training until validation scores don't improve for 200 rounds
# [500]	training's l2: 2.0896	valid_1's l2: 3.53677
# [1000]	training's l2: 1.56007	valid_1's l2: 3.03911
# [1500]	training's l2: 1.24478	valid_1's l2: 2.72804
# [2000]	training's l2: 1.04013	valid_1's l2: 2.53228
# [2500]	training's l2: 0.905251	valid_1's l2: 2.40615
# [3000]	training's l2: 0.79485	valid_1's l2: 2.30084
# [3500]	training's l2: 0.718121	valid_1's l2: 2.22996
# [4000]	training's l2: 0.650337	valid_1's l2: 2.16333
# [4500]	training's l2: 0.597491	valid_1's l2: 2.11902
# [5000]	training's l2: 0.550502	valid_1's l2: 2.07728
# [5500]	training's l2: 0.516448	valid_1's l2: 2.05074
# [6000]	training's l2: 0.48648	valid_1's l2: 2.02636
# [6500]	training's l2: 0.459252	valid_1's l2: 2.00374
# [7000]	training's l2: 0.435187	valid_1's l2: 1.98364
# [7500]	training's l2: 0.413416	valid_1's l2: 1.97037
# [8000]	training's l2: 0.394727	valid_1's l2: 1.95397
# [8500]	training's l2: 0.37794	valid_1's l2: 1.94017
# [9000]	training's l2: 0.362125	valid_1's l2: 1.92767
# [9500]	training's l2: 0.348486	valid_1's l2: 1.91852
# [10000]	training's l2: 0.335651	valid_1's l2: 1.90926
# [10500]	training's l2: 0.324445	valid_1's l2: 1.89857
# [11000]	training's l2: 0.313267	valid_1's l2: 1.8906
# [11500]	training's l2: 0.303433	valid_1's l2: 1.88449
# [12000]	training's l2: 0.292923	valid_1's l2: 1.87892
# [12500]	training's l2: 0.284927	valid_1's l2: 1.87395
# [13000]	training's l2: 0.27751	valid_1's l2: 1.86964
# [13500]	training's l2: 0.270162	valid_1's l2: 1.86648
# [14000]	training's l2: 0.263504	valid_1's l2: 1.86428
# [14500]	training's l2: 0.256837	valid_1's l2: 1.86101
# [15000]	training's l2: 0.251077	valid_1's l2: 1.85684
# [15500]	training's l2: 0.245252	valid_1's l2: 1.85323
# [16000]	training's l2: 0.240078	valid_1's l2: 1.85032
# [16500]	training's l2: 0.23527	valid_1's l2: 1.84906
# Early stopping, best iteration is:
# [16407]	training's l2: 0.236193	valid_1's l2: 1.84831
# MSE: 1.6141855087580474
# fold n°0
# Training until validation scores don't improve for 200 rounds
# [500]	training's l2: 2.1305	valid_1's l2: 3.25037
# [1000]	training's l2: 1.56921	valid_1's l2: 2.77222
# [1500]	training's l2: 1.26336	valid_1's l2: 2.49115
# [2000]	training's l2: 1.0566	valid_1's l2: 2.29471
# [2500]	training's l2: 0.910529	valid_1's l2: 2.17263
# [3000]	training's l2: 0.802447	valid_1's l2: 2.07306
# [3500]	training's l2: 0.723178	valid_1's l2: 1.99947
# [4000]	training's l2: 0.653353	valid_1's l2: 1.94358
# [4500]	training's l2: 0.5977	valid_1's l2: 1.89505
# [5000]	training's l2: 0.552942	valid_1's l2: 1.85863
# [5500]	training's l2: 0.513579	valid_1's l2: 1.83257
# [6000]	training's l2: 0.480337	valid_1's l2: 1.80665
# [6500]	training's l2: 0.452576	valid_1's l2: 1.78226
# [7000]	training's l2: 0.424682	valid_1's l2: 1.76787
# [7500]	training's l2: 0.403938	valid_1's l2: 1.75614
# [8000]	training's l2: 0.384722	valid_1's l2: 1.74245
# [8500]	training's l2: 0.366086	valid_1's l2: 1.72873
# [9000]	training's l2: 0.348732	valid_1's l2: 1.71951
# [9500]	training's l2: 0.335015	valid_1's l2: 1.70895
# [10000]	training's l2: 0.321654	valid_1's l2: 1.69972
# [10500]	training's l2: 0.309737	valid_1's l2: 1.69459
# [11000]	training's l2: 0.299575	valid_1's l2: 1.68967
# [11500]	training's l2: 0.290111	valid_1's l2: 1.68415
# [12000]	training's l2: 0.281823	valid_1's l2: 1.67706
# [12500]	training's l2: 0.274275	valid_1's l2: 1.67471
# [13000]	training's l2: 0.266769	valid_1's l2: 1.67043
# [13500]	training's l2: 0.259884	valid_1's l2: 1.66755
# [14000]	training's l2: 0.253161	valid_1's l2: 1.66515
# [14500]	training's l2: 0.246973	valid_1's l2: 1.66116
# [15000]	training's l2: 0.24021	valid_1's l2: 1.65821
# [15500]	training's l2: 0.234559	valid_1's l2: 1.65569
# [16000]	training's l2: 0.228685	valid_1's l2: 1.65483
# [16500]	training's l2: 0.223949	valid_1's l2: 1.65252
# [17000]	training's l2: 0.219605	valid_1's l2: 1.65084
# Early stopping, best iteration is:
# [17032]	training's l2: 0.219357	valid_1's l2: 1.65065
# fold n°1
# Training until validation scores don't improve for 200 rounds
# [500]	training's l2: 2.13901	valid_1's l2: 3.07259
# [1000]	training's l2: 1.5608	valid_1's l2: 2.59332
# [1500]	training's l2: 1.24437	valid_1's l2: 2.33068
# [2000]	training's l2: 1.0486	valid_1's l2: 2.18017
# [2500]	training's l2: 0.898435	valid_1's l2: 2.05294
# [3000]	training's l2: 0.794501	valid_1's l2: 1.96478
# [3500]	training's l2: 0.722286	valid_1's l2: 1.90174
# [4000]	training's l2: 0.649839	valid_1's l2: 1.84556
# [4500]	training's l2: 0.59736	valid_1's l2: 1.802
# [5000]	training's l2: 0.551655	valid_1's l2: 1.76538
# [5500]	training's l2: 0.511316	valid_1's l2: 1.73457
# [6000]	training's l2: 0.478737	valid_1's l2: 1.71379
# [6500]	training's l2: 0.449036	valid_1's l2: 1.69438
# [7000]	training's l2: 0.426045	valid_1's l2: 1.68022
# Early stopping, best iteration is:
# [6962]	training's l2: 0.428013	valid_1's l2: 1.67912
# fold n°2
# Training until validation scores don't improve for 200 rounds
# [500]	training's l2: 2.05504	valid_1's l2: 3.58852
# [1000]	training's l2: 1.52887	valid_1's l2: 3.12701
# [1500]	training's l2: 1.2319	valid_1's l2: 2.86951
# [2000]	training's l2: 1.0355	valid_1's l2: 2.68403
# [2500]	training's l2: 0.89976	valid_1's l2: 2.56433
# [3000]	training's l2: 0.796099	valid_1's l2: 2.47217
# [3500]	training's l2: 0.713043	valid_1's l2: 2.39772
# [4000]	training's l2: 0.64864	valid_1's l2: 2.35744
# [4500]	training's l2: 0.595685	valid_1's l2: 2.31031
# [5000]	training's l2: 0.555162	valid_1's l2: 2.27476
# [5500]	training's l2: 0.516103	valid_1's l2: 2.24223
# [6000]	training's l2: 0.483509	valid_1's l2: 2.21139
# [6500]	training's l2: 0.456405	valid_1's l2: 2.18805
# [7000]	training's l2: 0.430841	valid_1's l2: 2.16796
# [7500]	training's l2: 0.409085	valid_1's l2: 2.15099
# [8000]	training's l2: 0.391359	valid_1's l2: 2.13683
# [8500]	training's l2: 0.375675	valid_1's l2: 2.12442
# [9000]	training's l2: 0.360095	valid_1's l2: 2.11236
# [9500]	training's l2: 0.345712	valid_1's l2: 2.10277
# [10000]	training's l2: 0.333563	valid_1's l2: 2.09383
# [10500]	training's l2: 0.323318	valid_1's l2: 2.08515
# [11000]	training's l2: 0.313054	valid_1's l2: 2.07742
# [11500]	training's l2: 0.303713	valid_1's l2: 2.07194
# [12000]	training's l2: 0.293189	valid_1's l2: 2.06393
# [12500]	training's l2: 0.284621	valid_1's l2: 2.05741
# [13000]	training's l2: 0.27673	valid_1's l2: 2.05224
# [13500]	training's l2: 0.269633	valid_1's l2: 2.04699
# [14000]	training's l2: 0.263442	valid_1's l2: 2.04355
# [14500]	training's l2: 0.257076	valid_1's l2: 2.03885
# [15000]	training's l2: 0.251193	valid_1's l2: 2.03545
# [15500]	training's l2: 0.245605	valid_1's l2: 2.03277
# [16000]	training's l2: 0.240788	valid_1's l2: 2.03105
# [16500]	training's l2: 0.236616	valid_1's l2: 2.02963
# [17000]	training's l2: 0.232196	valid_1's l2: 2.02741
# [17500]	training's l2: 0.228505	valid_1's l2: 2.02531
# [18000]	training's l2: 0.224949	valid_1's l2: 2.02354
# [18500]	training's l2: 0.221696	valid_1's l2: 2.02178
# [19000]	training's l2: 0.217821	valid_1's l2: 2.01938
# [19500]	training's l2: 0.214565	valid_1's l2: 2.01728
# [20000]	training's l2: 0.211496	valid_1's l2: 2.01565
# Early stopping, best iteration is:
# [20260]	training's l2: 0.209828	valid_1's l2: 2.01491
# fold n°3
# Training until validation scores don't improve for 200 rounds
# [500]	training's l2: 2.09111	valid_1's l2: 3.08297
# [1000]	training's l2: 1.54068	valid_1's l2: 2.57742
# [1500]	training's l2: 1.24286	valid_1's l2: 2.29914
# [2000]	training's l2: 1.05637	valid_1's l2: 2.13955
# [2500]	training's l2: 0.924634	valid_1's l2: 2.01993
# [3000]	training's l2: 0.82602	valid_1's l2: 1.91908
# [3500]	training's l2: 0.742311	valid_1's l2: 1.83235
# [4000]	training's l2: 0.674345	valid_1's l2: 1.76662
# [4500]	training's l2: 0.623387	valid_1's l2: 1.72126
# [5000]	training's l2: 0.575589	valid_1's l2: 1.68071
# [5500]	training's l2: 0.535648	valid_1's l2: 1.64075
# [6000]	training's l2: 0.505216	valid_1's l2: 1.61862
# [6500]	training's l2: 0.478233	valid_1's l2: 1.59729
# [7000]	training's l2: 0.452807	valid_1's l2: 1.57804
# [7500]	training's l2: 0.430044	valid_1's l2: 1.5574
# [8000]	training's l2: 0.409266	valid_1's l2: 1.5404
# [8500]	training's l2: 0.390962	valid_1's l2: 1.5256
# [9000]	training's l2: 0.377188	valid_1's l2: 1.51543
# [9500]	training's l2: 0.360784	valid_1's l2: 1.49731
# [10000]	training's l2: 0.347144	valid_1's l2: 1.4881
# [10500]	training's l2: 0.336298	valid_1's l2: 1.48063
# [11000]	training's l2: 0.323767	valid_1's l2: 1.4714
# [11500]	training's l2: 0.312596	valid_1's l2: 1.46534
# [12000]	training's l2: 0.303021	valid_1's l2: 1.45875
# [12500]	training's l2: 0.294904	valid_1's l2: 1.4521
# [13000]	training's l2: 0.286358	valid_1's l2: 1.447
# [13500]	training's l2: 0.279123	valid_1's l2: 1.44198
# [14000]	training's l2: 0.27312	valid_1's l2: 1.43905
# [14500]	training's l2: 0.266754	valid_1's l2: 1.43608
# [15000]	training's l2: 0.261022	valid_1's l2: 1.43294
# [15500]	training's l2: 0.255607	valid_1's l2: 1.42997
# [16000]	training's l2: 0.250346	valid_1's l2: 1.42712
# [16500]	training's l2: 0.245358	valid_1's l2: 1.42433
# [17000]	training's l2: 0.240375	valid_1's l2: 1.4233
# Early stopping, best iteration is:
# [16928]	training's l2: 0.241209	valid_1's l2: 1.42298
# fold n°4
# Training until validation scores don't improve for 200 rounds
# [500]	training's l2: 2.12389	valid_1's l2: 3.32464
# [1000]	training's l2: 1.58248	valid_1's l2: 2.84869
# [1500]	training's l2: 1.25771	valid_1's l2: 2.54732
# [2000]	training's l2: 1.06071	valid_1's l2: 2.36263
# [2500]	training's l2: 0.925872	valid_1's l2: 2.23671
# [3000]	training's l2: 0.818046	valid_1's l2: 2.13662
# [3500]	training's l2: 0.736066	valid_1's l2: 2.05654
# [4000]	training's l2: 0.671527	valid_1's l2: 2.00482
# [4500]	training's l2: 0.617919	valid_1's l2: 1.95708
# [5000]	training's l2: 0.57016	valid_1's l2: 1.91479
# [5500]	training's l2: 0.53025	valid_1's l2: 1.88021
# [6000]	training's l2: 0.495291	valid_1's l2: 1.85171
# [6500]	training's l2: 0.467409	valid_1's l2: 1.82624
# [7000]	training's l2: 0.440755	valid_1's l2: 1.80089
# [7500]	training's l2: 0.418641	valid_1's l2: 1.78576
# [8000]	training's l2: 0.40062	valid_1's l2: 1.77206
# [8500]	training's l2: 0.383628	valid_1's l2: 1.75846
# [9000]	training's l2: 0.368324	valid_1's l2: 1.74682
# [9500]	training's l2: 0.353665	valid_1's l2: 1.73792
# [10000]	training's l2: 0.339834	valid_1's l2: 1.72792
# [10500]	training's l2: 0.327081	valid_1's l2: 1.71933
# [11000]	training's l2: 0.315819	valid_1's l2: 1.71327
# [11500]	training's l2: 0.30628	valid_1's l2: 1.7073
# [12000]	training's l2: 0.296442	valid_1's l2: 1.70046
# [12500]	training's l2: 0.287381	valid_1's l2: 1.69734
# [13000]	training's l2: 0.279322	valid_1's l2: 1.69335
# [13500]	training's l2: 0.272089	valid_1's l2: 1.6906
# [14000]	training's l2: 0.265622	valid_1's l2: 1.68723
# [14500]	training's l2: 0.259885	valid_1's l2: 1.68459
# [15000]	training's l2: 0.254231	valid_1's l2: 1.68148
# [15500]	training's l2: 0.248655	valid_1's l2: 1.68046
# Early stopping, best iteration is:
# [15344]	training's l2: 0.250495	valid_1's l2: 1.67937
# MSE: 1.6894058525430706

# %%
# 提交
# 此处statistic_pred.csv文件来自 https://github.com/Daya-Jin/rental-prediction 仓库
import math
stc = pd.read_csv('statistic_pred.csv')
result = []
for i in range(len(predictions_lgb)):
    if math.isnan(stc['Rental'][i]):
        result.append(predictions_lgb[i])
    else:
        result.append(stc['Rental'][i])
        
submit = pd.read_csv('submit_example.csv')
submit['Label'] = result
submit.to_csv('submit_seed_stc.csv', index=False)
